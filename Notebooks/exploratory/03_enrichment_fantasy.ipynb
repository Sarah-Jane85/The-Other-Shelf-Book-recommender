# %% [markdown]
# # Notebook 03 — Description Enrichment
# Scrapes StoryGraph to fill missing descriptions for books collected in Notebook 01.
# Also adds genres, moods, pace, and rating from StoryGraph.
# Output: `Data/Raw/non_western_fiction/collected.json`

# %%
# ── Notebook 03 — Merge GR + OL ────────────────────────────────────────────
import json, re
import pandas as pd
from pathlib import Path

REPO_ROOT  = Path().resolve().parents[1]
RAW_DIR    = REPO_ROOT / "Data" / "Raw" / "non_western_fantasy"
CLEAN_DIR  = REPO_ROOT / "Data" / "Clean"
CLEAN_DIR.mkdir(exist_ok=True)

ol_raw = pd.DataFrame(json.load(open(RAW_DIR / "ol_genre_first.json")))
gr_raw = pd.read_csv(RAW_DIR / "goodreads_with_descriptions.csv")

print(f"✅ Loaded")
print(f"   OL books:         {len(ol_raw):,}")
print(f"   Goodreads books:  {len(gr_raw):,}")
print(f"\n   OL columns:  {list(ol_raw.columns)}")
print(f"   GR columns:  {list(gr_raw.columns)}")
# Out:
# ✅ Loaded
#    OL books:         4,364
#    Goodreads books:  2,129
#
#    OL columns:  ['title', 'author', 'year_published', 'cover_url', 'avg_rating', 'num_ratings', 'subjects', 'source', 'source_url', 'source_tag', 'query', 'description']
#    GR columns:  ['title', 'author', 'goodreads_url', 'cover_url', 'avg_rating', 'num_ratings', 'year_published', 'shelf', 'description']

# %%
# ── Cell 2 — Filter OL noise ────────────────────────────────────────────────
WESTERN_NOISE_AUTHORS = {
    "edgar rice burroughs", "h. rider haggard", "rudyard kipling",
    "joseph conrad", "wilbur smith", "james michener", "john buchan",
    "arthur conan doyle", "h.g. wells", "jules verne",
}

NOISE_SUBJECTS = {
    "tarzan", "colonial", "colonialism", "imperialism",
    "safari", "big game hunting", "missionaries",
}

CULTURAL_SIGNALS = {
    "yoruba", "igbo", "akan", "zulu", "xhosa", "orisha", "anansi",
    "afrofuturism", "africanfuturism", "african fantasy",
    "yokai", "kami", "oni", "kitsune", "tengu", "wuxia", "xianxia",
    "cultivation", "jade emperor", "chinese fantasy", "japanese fantasy",
    "korean fantasy", "manhwa", "manhua",
    "djinn", "jinn", "ifrit", "persian", "ottoman", "mughal", "arabian",
    "hindu", "vedic", "mahabharata", "ramayana", "rakshasa", "asura",
    "aztec", "mayan", "inca", "nahua", "mesoamerican", "latin american fantasy",
    "curandera", "brujeria",
    "native american", "indigenous", "navajo", "lakota", "ojibwe",
    "anishinaabe", "first nations",
    "maori", "aboriginal", "polynesian", "pacific islander",
    "filipino", "aswang", "diwata", "babaylan",
    "vietnamese", "thai fantasy",
    "magical realism", "speculative fiction",
}

TRUSTED_QUERIES = {
    "afrofuturism", "africanfuturism", "wuxia", "xianxia",
    "fantasy yoruba", "fantasy igbo", "fantasy akan", "fantasy orisha",
    "fantasy anansi", "fantasy kitsune", "fantasy yokai", "fantasy aswang",
    "fantasy djinn", "fantasy mahabharata", "fantasy ramayana", "fantasy aztec",
    "fantasy curandera",
}

def ol_passes_filter(row):
    if str(row.get("author", "")).lower().strip() in WESTERN_NOISE_AUTHORS:
        return False
    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()
    if any(n in subjects_text for n in NOISE_SUBJECTS):
        return False
    if row.get("query") in TRUSTED_QUERIES:
        return True
    text = subjects_text + " " + str(row.get("title", "")).lower()
    return any(signal in text for signal in CULTURAL_SIGNALS)

mask        = ol_raw.apply(ol_passes_filter, axis=1)
ol_filtered = ol_raw[mask].copy().reset_index(drop=True)
ol_removed  = ol_raw[~mask].copy().reset_index(drop=True)

print(f"── OL filter results ──")
print(f"  Before:  {len(ol_raw):,}")
print(f"  After:   {len(ol_filtered):,}")
print(f"  Removed: {len(ol_removed):,}")
print(f"\n  Sample removed (first 10):")
for _, r in ol_removed.head(10).iterrows():
    print(f"    {r['title']} — {r['author']}")
# Out:
# ── OL filter results ──
#   Before:  4,364
#   After:   1,079
#   Removed: 3,285
#
#   Sample removed (first 10):
#     Tarzan of the Apes — Edgar Rice Burroughs
#     She — H. Rider Haggard
#     King Solomon's Mines — H. Rider Haggard
#     The Secret Agent — Joseph Conrad
#     Cinq semaines en ballon — Jules Verne
#     The Return of Tarzan — Edgar Rice Burroughs
#     The People of the Mist — H. Rider Haggard
#     The Grey Fairy Book — Andrew Lang
#     Tarzan the Untamed (Book #7) — Edgar Rice Burroughs
#     The Beasts of Tarzan (Classic Ace SF, F-203) — Edgar Rice Burroughs

# %%
# ── Cell 3 — Audit removed books ───────────────────────────────────────────
print("Sample removed books by query tag:\n")

for tag in ol_removed["source_tag"].unique():
    sample = ol_removed[ol_removed["source_tag"] == tag].head(5)
    print(f"── {tag} ──")
    for _, r in sample.iterrows():
        subj_preview = str(r["subjects"])[:80] if r["subjects"] else "no subjects"
        print(f"  {r['title']} — {r['author']}")
        print(f"    subjects: {subj_preview}")
    print()
# Out:
# Sample removed books by query tag:
#
# ── africa ──
#   Tarzan of the Apes — Edgar Rice Burroughs
#     subjects: ['British in fiction', 'Historical Fiction', 'Wild men in fiction', 'American Ad
#   She — H. Rider Haggard
#     subjects: ['Fiction in English', 'Adventure and adventurers', 'Reincarnation', 'Fiction in
#   King Solomon's Mines — H. Rider Haggard
#     subjects: ["Children's fiction", 'Mines and mineral resources, fiction', 'Adventure and ad
#   The Secret Agent — Joseph Conrad
#     subjects: ['Anarchists, fiction', 'Conspiracies, fiction', 'Bombings, fiction', 'Terrorism
#   Cinq semaines en ballon — Jules Verne
#     subjects: ['Travel', 'Hot air balloons', 'Description and travel', 'Fiction', 'Classic Lit
#
# ── zulu ──
#   Black Heart and White Heart — H. Rider Haggard
#     subjects: ['Classic Literature', 'Fiction', 'Fiction, romance, general', 'Fiction, fantasy
#
# ── anansi ──
#   LiTTscapes - Landscapes of Fiction from Trinidad and Tobago — Kris Rampersad
#     subjects: ['Literature', 'Fiction', 'Trinidad and Tobago', 'Caribbean', 'society', 'politi
#
# ── afrofuturism ──
#   We Travel the Space Ways — Henriette Gunkel
#     subjects: ['Civilization, history', 'Afrofuturism', 'African Art', 'History and criticism'
#
# ── chinese ──
#   Herland — Charlotte Perkins Gilman
#     subjects: ['Utopias', 'Fiction', 'Women', 'Matriarchat', 'Utopie', 'Classic Literature', '
#   The Princess and the Goblin — George MacDonald
#     subjects: ['Classic Literature', 'Fantasy', 'Fiction', 'Juvenile Fiction', 'Juvenile Liter
#   Women in Love — D. H. Lawrence
#     subjects: ['Romance', 'Classic Literature', 'Male friendship', 'Open Library Staff Picks',
#   The Invisible Man — H. G. Wells
#     subjects: ['Ciencia-ficción', 'Classic Literature', 'Fiction', 'Mentally ill', 'Science Fi
#   Anne of Green Gables — Lucy Maud Montgomery
#     subjects: ['Fiction', 'Juvenile fiction', 'Country life', 'Friendship', 'Orphans', 'Friend
#
# ── japanese ──
#   Le avventure di Pinocchio — Carlo Collodi
#     subjects: ['Fantasy', 'Puppets', 'Fiction', 'Fairy tales', "Children's stories, Italian",
#   Blue bamboo — 太宰 治
#     subjects: ['Translations into English', 'Social life and customs', 'Fiction', 'New York Ti
#   Bleach — Tite Kubo
#     subjects: ['Graphic novels', 'Translations into English', 'High school students', 'Soul',
#   Grand Fantasy Designs - Notes — Felix Ode
#     subjects: no subjects
#   Naruto 5 — Masashi Kishimoto
#     subjects: ['Pariahs', 'Graphic novels', 'Fiction', 'Ninja', 'Competition (Psychology)', 'C
#
# ── korean ──
#   Watership Down — Richard Adams
#     subjects: ['Rabbits', 'Adventure and adventurers', 'Open Library Staff Picks', 'Fiction',
#   Charlie and the Great Glass Elevator — Roald Dahl
#     subjects: ['Charlie Bucket (Fictitious character)', 'Juvenile fiction', "Children's fictio
#   The Lion, the Witch and the Wardrobe — C. S. Lewis
#     subjects: ['the Blitz', 'fauns', 'Turkish Delight', 'lions', "English Children's stories",
#   Momo oder Die seltsame Geschichte von den Zeit-Dieben und von dem Kind, das den Menschen die gestohlene Zeit zurückbrachte — Michael Ende
#     subjects: ['Girls', 'Juvenile fiction', 'Time', 'Literatura infantil alemana', 'fiction',
#   The Prince — Niccolò Machiavelli
#     subjects: ['Political science, early works to 1800', 'Machiavel, Nicolas, 1469-1527. Princ
#
# ── south_asian ──
#   Dracula — Bram Stoker
#     subjects: ['English literature', 'Fiction', 'Horror', 'Horror stories', 'Horror tales', 'M
#   The War of the Worlds — H. G. Wells
#     subjects: ['Imaginary wars and battles', 'Juvenile fiction', 'Space warfare', 'Science Fic
#   Harry Potter and the Order of the Phoenix — J. K. Rowling
#     subjects: ["Children's Books/Ages 9-12 Fiction", 'Witches and warlocks', 'Juvenile audienc
#   Harry Potter and the Half-Blood Prince — J. K. Rowling
#     subjects: ['orphans', 'foster homes', 'romans', 'magie', 'adolescence', 'Quill Award winne
#   The water-babies: a fairy tale for a land-baby — Charles Kingsley
#     subjects: ['Chimney sweeps', 'Fiction', 'Fairy tales', 'Open Library Staff Picks', 'Fictio
#
# ── filipino ──
#   Dream factories of a former colony — José B. Capino
#     subjects: ['Motion pictures', 'Culture in motion pictures', 'Motion pictures and globaliza
#   Dream Factories of a Former Colony — Jos Capino
#     subjects: no subjects
#   Dream Factories of a Former Colony — Jose B. Capino
#     subjects: ['Motion pictures, asia', 'Globalization', 'United states, in motion pictures',
#   Dean Worcester's Fantasy Islands — Mark Rice
#     subjects: ['Political and social views', 'Colonial administrators', 'Biography', 'Photogra
#   Fantasy production — Neferti Xina M. Tadiar
#     subjects: ['Economic conditions', 'Politics and government', 'Social conditions', 'Philipp
#
# ── southeast_asian ──
#   Coraline — Neil Gaiman
#     subjects: ['Fantasy', 'Paranormal fiction', 'Juvenile fiction', 'Graphic novels', "Childre
#   Voyage au Centre de la Terre — Jules Verne
#     subjects: ['Fiction', 'Science fiction', 'Imaginary Voyages', 'Imaginary voyages in fictio
#   A Storm of Swords — George R. R. Martin
#     subjects: ['New York Times bestseller', 'nyt:mass_market_paperback=2011-06-04', 'Seven Kin
#   The Lost Hero — Rick Riordan
#     subjects: ['Serie:The_Heroes_of_Olympus', 'nyt:chapter_books=2010-11-06', 'New York Times
#   Flight in to Fantasy — Melissa Carroll
#     subjects: ['Tales']
#
# ── middle_eastern ──
#   Alexander Korda's The Thief of Bagdad — Philip Leibfried
#     subjects: ['Thief of Bagdad (Motion picture)']
#   Spice Road — Maiya Ibrahim
#     subjects: no subjects
#   Serpent Sea — Maiya Ibrahim
#     subjects: no subjects
#   Fables, Vol. 7 — Bill Willingham
#     subjects: ['Animals', 'Characters and characteristics in literature', 'Revolutions', 'Comi
#   Muslim Evangelism — Norman Carlson
#     subjects: no subjects
#
# ── latin_american ──
#   The Book of Dragons — Edith Nesbit
#     subjects: ['Juvenile fiction', "Children's stories, English", 'Fiction', 'Fairy tales', 'D
#   The Magic City — Edith Nesbit
#     subjects: ['Fantasy', 'Cities and towns', 'Juvenile fiction', 'Fiction', "Children's ficti
#   The Sword of Kaigen — M. L. Wang
#     subjects: ['Fiction', 'Fiction, fantasy, general', 'Fantasy', 'High Fantasy', 'Fiction, fa
#   Fantasy Art — Maya Esmail
#     subjects: no subjects
#   Mystical Fantasy — Maya Nadin
#     subjects: no subjects
#
# ── indigenous_americas ──
#   Tribal Fantasies — J. Mackay
#     subjects: no subjects
#   Baum's American Fairy Tales — L. Frank Baum
#     subjects: ["Children's stories, American", 'Juvenile Fiction', 'Fiction', 'Fantasy', 'Fair
#   Anthology of Short Stories - Volume II — Watts, John
#     subjects: no subjects
#   Neo-realism In Contemporary American Fiction.(Postmodern Studies 5) — Kristiaan Versluys
#     subjects: ['Modernism (Literature)', 'Congresses', 'Postmodernism', 'Realism in literature
#   Conscious : Shikoba Blue Series — DonnaLee Grimsley
#     subjects: no subjects
#
# ── oceania ──
#   Conference papers, NZARE 2001 — New Zealand Association for Research in Education. Conference
#     subjects: ['Education', 'Congresses']
#   Alitji in Dreamland = — Nancy Sheppard
#     subjects: ['Bilingual', 'Fantasy', 'Pitjantjatjara language materials']
#   L'Île mystérieuse — Jules Verne
#     subjects: ['Popular Print Disabled Books', 'French Adventure stories', 'French language ma
#   Skeleton crew — Stephen King
#     subjects: ['American Horror tales', 'nested narrative', 'Novellas', 'alcoholism', 'anecdot
#   Pippi Langstrump i Söderhavet — Astrid Lindgren
#     subjects: ['Humorous stories', "Children's stories", 'Juvenile fiction', 'Island of the Pa

# %%
# ── Cell 4 — Smarter filter ─────────────────────────────────────────────────

# These broad queries return too much western noise — don't trust them alone
NOISY_QUERIES = {
    "fantasy korean", "fantasy indian", "fantasy india",
    "fantasy chinese", "fantasy japan", "fantasy japanese",
    "fantasy african", "fantasy africa", "science fiction africa",
    "fantasy latin american", "science fiction latin american",
    "fantasy native american", "fantasy indigenous",
    "fantasy arabian", "fantasy persian", "fantasy islamic",
    "fantasy vietnamese", "fantasy thai", "fantasy philippine",
    "fantasy aboriginal", "fantasy pacific islander",
    "fantasy maori", "fantasy polynesian",
    "fantasy maya", "fantasy mayan", "fantasy inca", "fantasy aztec",
    "fantasy zulu", "fantasy navajo", "fantasy lakota",
}

# These specific queries are reliable — trust them without needing subject signals
TRUSTED_QUERIES = {
    "afrofuturism", "africanfuturism", "wuxia", "xianxia",
    "fantasy yoruba", "fantasy igbo", "fantasy akan", "fantasy orisha",
    "fantasy anansi", "fantasy kitsune", "fantasy yokai", "fantasy aswang",
    "fantasy djinn", "fantasy mahabharata", "fantasy ramayana",
    "fantasy aztec", "fantasy curandera", "fantasy cultivation",
    "fantasy filipino", "fantasy vietnamese", "fantasy thai",
    "fantasy philippine", "fantasy ottoman", "fantasy mughal",
    "fantasy aboriginal", "fantasy maori", "fantasy pacific islander",
    "fantasy polynesian", "fantasy navajo", "fantasy lakota",
    "fantasy persian", "fantasy arabian", "fantasy islamic",
}

WESTERN_NOISE_AUTHORS = {
    "edgar rice burroughs", "h. rider haggard", "rudyard kipling",
    "joseph conrad", "wilbur smith", "james michener", "john buchan",
    "arthur conan doyle", "h.g. wells", "jules verne",
    "charlotte perkins gilman", "george macdonald", "d. h. lawrence",
    "lucy maud montgomery", "carlo collodi", "neil gaiman",
    "george r. r. martin", "rick riordan", "j. k. rowling",
    "bram stoker", "edith nesbit", "l. frank baum",
    "richard adams", "roald dahl", "c. s. lewis",
    "stephen king", "astrid lindgren", "bill willingham",
}

NOISE_SUBJECTS = {
    "tarzan", "colonialism", "imperialism",
    "safari", "big game hunting", "missionaries",
}

CULTURAL_SIGNALS = {
    "yoruba", "igbo", "akan", "zulu", "xhosa", "orisha", "anansi",
    "afrofuturism", "africanfuturism", "african fantasy", "african fiction",
    "yokai", "kami", "oni", "kitsune", "tengu", "wuxia", "xianxia",
    "cultivation", "jade emperor", "chinese fantasy", "japanese fantasy",
    "korean fantasy", "manhwa", "manhua", "manga",
    "djinn", "jinn", "ifrit", "persian", "ottoman", "mughal", "arabian",
    "hindu", "vedic", "mahabharata", "ramayana", "rakshasa", "asura",
    "aztec", "mayan", "inca", "nahua", "mesoamerican",
    "curandera", "brujeria", "latin american",
    "native american", "indigenous", "navajo", "lakota", "ojibwe",
    "anishinaabe", "first nations",
    "maori", "aboriginal", "polynesian", "pacific islander",
    "filipino", "aswang", "diwata", "babaylan",
    "vietnamese", "thai", "korean", "japanese", "chinese",
    "magical realism", "speculative fiction", "afrofuturism",
    "african", "south asian", "southeast asian",
}

def ol_passes_filter(row):
    author = str(row.get("author", "")).lower().strip()
    query  = row.get("query", "")

    # Always remove known western noise authors
    if author in WESTERN_NOISE_AUTHORS:
        return False

    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()

    # Remove noise subjects regardless of query
    if any(n in subjects_text for n in NOISE_SUBJECTS):
        return False

    # Trusted specific queries — keep unless western author
    if query in TRUSTED_QUERIES:
        return True

    # For noisy broad queries — require cultural signal in subjects or title
    if query in NOISY_QUERIES:
        text = subjects_text + " " + str(row.get("title", "")).lower()
        return any(signal in text for signal in CULTURAL_SIGNALS)

    # Default: keep
    return True

mask        = ol_raw.apply(ol_passes_filter, axis=1)
ol_filtered = ol_raw[mask].copy().reset_index(drop=True)
ol_removed  = ol_raw[~mask].copy().reset_index(drop=True)

print(f"── OL filter results ──")
print(f"  Before:  {len(ol_raw):,}")
print(f"  After:   {len(ol_filtered):,}")
print(f"  Removed: {len(ol_removed):,}")
print(f"\n  Removed by source_tag:")
for tag, count in ol_removed["source_tag"].value_counts().items():
    print(f"    {tag:25s}: {count:,}")
print(f"\n  Kept by source_tag:")
for tag, count in ol_filtered["source_tag"].value_counts().items():
    print(f"    {tag:25s}: {count:,}")
# Out:
# ── OL filter results ──
#   Before:  4,364
#   After:   2,734
#   Removed: 1,630
#
#   Removed by source_tag:
#     japanese                 : 553
#     south_asian              : 396
#     africa                   : 372
#     latin_american           : 143
#     chinese                  : 123
#     korean                   : 16
#     indigenous_americas      : 10
#     southeast_asian          : 4
#     oceania                  : 4
#     anansi                   : 3
#     filipino                 : 2
#     middle_eastern           : 2
#     zulu                     : 1
#     afrofuturism             : 1
#
#   Kept by source_tag:
#     japanese                 : 1,230
#     chinese                  : 510
#     africa                   : 263
#     middle_eastern           : 202
#     latin_american           : 128
#     south_asian              : 79
#     korean                   : 74
#     afrofuturism             : 58
#     wuxia                    : 43
#     southeast_asian          : 35
#     filipino                 : 28
#     oceania                  : 23
#     xianxia                  : 21
#     indigenous_americas      : 15
#     anansi                   : 13
#     igbo                     : 3
#     akan                     : 3
#     orisha                   : 3
#     zulu                     : 2
#     yoruba                   : 1

# %%
# ── Quick sanity check ──────────────────────────────────────────────────────
check_titles = ["Spice Road", "Serpent Sea", "The Sword of Kaigen", "Bleach", "Naruto"]
for t in check_titles:
    found = ol_filtered[ol_filtered["title"].str.contains(t, case=False, na=False)]
    status = "✅ KEPT" if len(found) > 0 else "❌ REMOVED"
    print(f"  {status}: {t}")
# Out:
#   ✅ KEPT: Spice Road
#   ✅ KEPT: Serpent Sea
#   ❌ REMOVED: The Sword of Kaigen
#   ✅ KEPT: Bleach
#   ✅ KEPT: Naruto

# %%
# ── Cell 5 — Remove comics/manga/graphic novels + fix edge cases ────────────

COMIC_SUBJECTS = {
    "graphic novel", "graphic novels", "comics", "comic book",
    "manga", "manhwa", "manhua", "comic strip",
}

COMIC_TITLE_SIGNALS = [
    "vol.", "volume", "#1", "#2", "#3", "issue", "omnibus",
]

def is_comic(row):
    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()
    if any(c in subjects_text for c in COMIC_SUBJECTS):
        return True
    # Catch manga/comic series by title patterns
    title_lower = str(row.get("title", "")).lower()
    if any(sig in title_lower for sig in COMIC_TITLE_SIGNALS):
        return True
    return False

# Also add M.L. Wang to a manual keeplist — good book, sparse OL subjects
MANUAL_KEEP_TITLES = {
    "the sword of kaigen",
}

def final_filter(row):
    if str(row.get("title", "")).lower().strip() in MANUAL_KEEP_TITLES:
        return True
    if is_comic(row):
        return False
    return True

mask2       = ol_filtered.apply(final_filter, axis=1)
ol_clean    = ol_filtered[mask2].copy().reset_index(drop=True)
ol_removed2 = ol_filtered[~mask2].copy().reset_index(drop=True)

print(f"── Comic/manga filter ──")
print(f"  Before:  {len(ol_filtered):,}")
print(f"  After:   {len(ol_clean):,}")
print(f"  Removed: {len(ol_removed2):,}")
print(f"\n  Sample removed:")
for _, r in ol_removed2.head(10).iterrows():
    print(f"    {r['title']} — {r['author']}")

# Verify
for t in ["The Sword of Kaigen", "Bleach", "Naruto", "Spice Road"]:
    found = ol_clean[ol_clean["title"].str.contains(t, case=False, na=False)]
    print(f"  {'✅' if len(found) else '❌'} {t}")
# Out:
# ── Comic/manga filter ──
#   Before:  2,734
#   After:   1,647
#   Removed: 1,087
#
#   Sample removed:
#     Hotel Africa Volume 2 (Hotel Africa) — Hee Jung Park
#     Hotel Africa Volume 1 — Hee Jung Park
#     Mobile suit Gundam seed — Iwase, Masatsugu.
#     Rapport final — Séminaire Africana 90 "L'imaginaire dans le théâtre et la b.d. africaine" (1990 La Chaux-de-Fonds, Switzerland)
#     Frankenstein or The Modern Prometheus — Mary Shelley
#     Keeping It Unreal — Darieck Scott
#     Marwe: Into the Land of the Dead [An East African Legend] (Graphic Myths and Legends) — Marie P. Croall
#     Picking Up The Ghost — Tone Milazzo
#     Bayou Volume Two — Jeremy Love
#     Bayou — Jeremy Love
#   ❌ The Sword of Kaigen
#   ❌ Bleach
#   ❌ Naruto
#   ✅ Spice Road

# %%
# ── Cell 5 — Fixed version ──────────────────────────────────────────────────

COMIC_SUBJECTS = {
    "graphic novel", "graphic novels", "comics", "comic book",
    "comic strip", "sequential art",
}

# Only remove by title pattern if it also has comic subjects
# (vol.1 alone is not enough — "The Sword of Kaigen Vol.1" is still a novel)
MANUAL_KEEP_TITLES = {
    "the sword of kaigen",
}

MANUAL_REMOVE_AUTHORS = {
    "mary shelley",  # Frankenstein — not relevant
}

def is_comic(row):
    title_lower   = str(row.get("title", "")).lower().strip()
    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()

    # Manual keep always wins
    if title_lower in MANUAL_KEEP_TITLES:
        return False

    # Manual remove authors
    if str(row.get("author", "")).lower().strip() in MANUAL_REMOVE_AUTHORS:
        return True

    # Only flag as comic if subjects explicitly say so
    if any(c in subjects_text for c in COMIC_SUBJECTS):
        return True

    return False

ol_clean    = ol_filtered[~ol_filtered.apply(is_comic, axis=1)].copy().reset_index(drop=True)
ol_removed2 = ol_filtered[ol_filtered.apply(is_comic, axis=1)].copy().reset_index(drop=True)

print(f"── Comic filter ──")
print(f"  Before:  {len(ol_filtered):,}")
print(f"  After:   {len(ol_clean):,}")
print(f"  Removed: {len(ol_removed2):,}")
print(f"\n  Sample removed:")
for _, r in ol_removed2.head(10).iterrows():
    print(f"    {r['title']} — {r['author']}")

print()
for t in ["The Sword of Kaigen", "Bleach", "Naruto", "Spice Road", "Frankenstein"]:
    found = ol_clean[ol_clean["title"].str.contains(t, case=False, na=False)]
    print(f"  {'✅ KEPT' if len(found) else '❌ REMOVED'}: {t}")
# Out:
# ── Comic filter ──
#   Before:  2,734
#   After:   1,679
#   Removed: 1,055
#
#   Sample removed:
#     Hotel Africa Volume 2 (Hotel Africa) — Hee Jung Park
#     Hotel Africa Volume 1 — Hee Jung Park
#     Mobile suit Gundam seed — Iwase, Masatsugu.
#     Rapport final — Séminaire Africana 90 "L'imaginaire dans le théâtre et la b.d. africaine" (1990 La Chaux-de-Fonds, Switzerland)
#     Frankenstein or The Modern Prometheus — Mary Shelley
#     Keeping It Unreal — Darieck Scott
#     Marwe: Into the Land of the Dead [An East African Legend] (Graphic Myths and Legends) — Marie P. Croall
#     Picking Up The Ghost — Tone Milazzo
#     Bayou Volume Two — Jeremy Love
#     Bayou — Jeremy Love
#
#   ❌ REMOVED: The Sword of Kaigen
#   ❌ REMOVED: Bleach
#   ❌ REMOVED: Naruto
#   ✅ KEPT: Spice Road
#   ❌ REMOVED: Frankenstein

# %%
# ── Debug Sword of Kaigen ───────────────────────────────────────────────────
sword = ol_raw[ol_raw["title"].str.contains("Sword of Kaigen", case=False, na=False)]
for _, r in sword.iterrows():
    print(f"Title:    {r['title']}")
    print(f"Author:   {r['author']}")
    print(f"Subjects: {r['subjects']}")
    print(f"Query:    {r['query']}")
# Out:
# Title:    The Sword of Kaigen
# Author:   M. L. Wang
# Subjects: ['Fiction', 'Fiction, fantasy, general', 'Fantasy', 'High Fantasy', 'Fiction, fantasy, epic', 'FICTION / Fantasy / Epic', 'Epic Fantasy', 'Magic', 'Science Fiction & Fantasy']
# Query:    fantasy maya

# %%
# ── Cell 5 — Final filter logic ─────────────────────────────────────────────

WESTERN_NOISE_AUTHORS = {
    "edgar rice burroughs", "h. rider haggard", "rudyard kipling",
    "joseph conrad", "wilbur smith", "james michener", "john buchan",
    "arthur conan doyle", "h.g. wells", "jules verne",
    "charlotte perkins gilman", "george macdonald", "d. h. lawrence",
    "lucy maud montgomery", "carlo collodi", "neil gaiman",
    "george r. r. martin", "rick riordan", "j. k. rowling",
    "bram stoker", "edith nesbit", "l. frank baum",
    "richard adams", "roald dahl", "c. s. lewis",
    "stephen king", "astrid lindgren", "bill willingham",
    "mary shelley", "niccolò machiavelli", "michael ende",
    "charles kingsley", "andrew lang",
}

NOISE_SUBJECTS = {
    "tarzan", "colonialism", "imperialism",
    "safari", "big game hunting", "missionaries",
}

COMIC_SUBJECTS = {
    "graphic novel", "graphic novels", "comics", "comic book",
    "comic strip", "sequential art",
}

def ol_final_filter(row):
    author        = str(row.get("author", "")).lower().strip()
    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()

    # Remove known western authors
    if author in WESTERN_NOISE_AUTHORS:
        return False

    # Remove noise subjects
    if any(n in subjects_text for n in NOISE_SUBJECTS):
        return False

    # Remove comics/graphic novels
    if any(c in subjects_text for c in COMIC_SUBJECTS):
        return False

    return True

ol_clean    = ol_raw[ol_raw.apply(ol_final_filter, axis=1)].copy().reset_index(drop=True)
ol_removed  = ol_raw[~ol_raw.apply(ol_final_filter, axis=1)].copy().reset_index(drop=True)

print(f"── Final OL filter ──")
print(f"  Before:  {len(ol_raw):,}")
print(f"  After:   {len(ol_clean):,}")
print(f"  Removed: {len(ol_removed):,}")
print(f"\n  Kept by source_tag:")
for tag, count in ol_clean["source_tag"].value_counts().items():
    print(f"    {tag:25s}: {count:,}")

print()
for t in ["The Sword of Kaigen", "Spice Road", "Tarzan", "Harry Potter", "Naruto"]:
    found = ol_clean[ol_clean["title"].str.contains(t, case=False, na=False)]
    print(f"  {'✅ KEPT' if len(found) else '❌ REMOVED'}: {t}")
# Out:
# ── Final OL filter ──
#   Before:  4,364
#   After:   2,884
#   Removed: 1,480
#
#   Kept by source_tag:
#     japanese                 : 607
#     africa                   : 546
#     chinese                  : 525
#     south_asian              : 440
#     latin_american           : 256
#     middle_eastern           : 189
#     korean                   : 73
#     afrofuturism             : 58
#     wuxia                    : 43
#     southeast_asian          : 32
#     filipino                 : 26
#     indigenous_americas      : 23
#     oceania                  : 22
#     xianxia                  : 21
#     anansi                   : 13
#     igbo                     : 3
#     orisha                   : 3
#     zulu                     : 2
#     yoruba                   : 1
#     akan                     : 1
#
#   ✅ KEPT: The Sword of Kaigen
#   ✅ KEPT: Spice Road
#   ❌ REMOVED: Tarzan
#   ✅ KEPT: Harry Potter
#   ❌ REMOVED: Naruto

# %%
# ── Who are the most common authors in ol_clean? ───────────────────────────
author_counts = ol_clean["author"].value_counts()

print("Top 100 authors in filtered OL data:")
print(author_counts.head(100).to_string())
# Out:
# Top 100 authors in filtered OL data:
# author
#                               107
# Joseph Li                      13
# Maya Daniels                   13
# L. A. Banks                    10
# Dr. Seuss                      10
# 村上春樹                           10
# Daisy Meadows                  10
# Tao Wong                       10
# Lynne Reid Banks               10
# Vicki Corona                   10
# Gillian Rubinstein              9
# Octavia E. Butler               8
# Reggie ROBINSON                 8
# Edgar Allan Poe                 7
# Lian Hearn                      7
# Erica BAKER                     7
# Hasaway Anime Corner            6
# Scott Walker                    6
# Philip Kerr                     6
# Tara Maya                       6
# Erin Hunter                     5
# Lauren Beukes                   5
# Samuel R. Delany                5
# Piers Anthony                   5
# Nalo Hopkinson                  5
# A. J. Hartley                   5
# Rochelle Alers                  5
# Mary Pope Osborne               5
# Lewis Carroll                   5
# Yuan, Mei                       5
# Henriette Barkow                5
# Yoshitaka Amano                 5
# Steve Bein                      5
# Nathaniel Hawthorne             5
# Mo Xiang Tong Xiu               5
# Jami Fairleigh                  5
# Roshani Chokshi                 5
# Tom Deitz                       5
# John Peragine                   5
# Carmen Kern                     5
# Maya Kaathryn Bohnhoff          5
# Nnedi Okorafor                  4
# Katie Chase                     4
# Tracey West                     4
# P. Djèlí Clark                  4
# Virginia Hamilton               4
# Mike Resnick                    4
# James Axler                     4
# Reynaldo Anderson               4
# J.R.R. Tolkien                  4
# 刘慈欣                             4
# Cyril Birch                     4
# John DeFrancis                  4
# Charles de Lint                 4
# Kylie Chan                      4
# Jian'guo Li                     4
# Qingfu Ma                       4
# Yuwo                            4
# Grace Divine                    4
# Takako Samejima                 4
# Jay Kristoff                    4
# Muhammad Vandestra              4
# Kara Dalkey                     4
# Tsuji, Nobuo                    4
# Antoine de Saint-Exupéry        4
# Fabulous Books                  4
# Petals & Pastels                4
# Hae-jin Sin                     4
# Chitra Banerjee Divakaruni      4
# Mercedes Lackey                 4
# Harold MacGrath                 4
# Kailin Gow                      4
# نوشیروان‌پور، پیوند،            4
# Amos Tutuola                    3
# Marnee Patricia Banks           3
# B. Catling                      3
# Paul Theroux                    3
# Mark Twain                      3
# Rivers Solomon                  3
# Sheree Renée Thomas             3
# Kayla Perrin                    3
# Francine Craft                  3
# Ronald L. Smith                 3
# Jane M. Lindskold               3
# Luis Senarens                   3
# Various                         3
# James Rollins                   3
# Michael Bishop                  3
# Jon Courtenay Grimwood          3
# Carl Bowen                      3
# Ellen Datlow                    3
# Christopher Paolini             3
# Ling Lee                        3
# Mei Zihan                       3
# Susan J. Napier                 3
# Nagaru Tanigawa                 3
# Annie Dalton                    3
# Jason Rohan                     3
# Miyuki Miyabe                   3
# Olivia Vieweg                   3

# %%
# ── Cell 6 — Updated western author blocklist ───────────────────────────────
WESTERN_NOISE_AUTHORS = {
    # Original list
    "edgar rice burroughs", "h. rider haggard", "rudyard kipling",
    "joseph conrad", "wilbur smith", "james michener", "john buchan",
    "arthur conan doyle", "h.g. wells", "jules verne",
    "charlotte perkins gilman", "george macdonald", "d. h. lawrence",
    "lucy maud montgomery", "carlo collodi", "neil gaiman",
    "george r. r. martin", "rick riordan", "j. k. rowling",
    "bram stoker", "edith nesbit", "l. frank baum",
    "richard adams", "roald dahl", "c. s. lewis",
    "stephen king", "astrid lindgren", "bill willingham",
    "mary shelley", "niccolò machiavelli", "michael ende",
    "charles kingsley", "andrew lang",
    # New additions from top 100 audit
    "dr. seuss", "lewis carroll", "edgar allan poe",
    "nathaniel hawthorne", "mark twain", "antoine de saint-exupéry",
    "christopher paolini", "j.r.r. tolkien", "mercedes lackey",
    "piers anthony", "mary pope osborne", "daisy meadows",
    "erin hunter", "paul theroux", "harold macgrath",
    "charles de lint", "james rollins",
}

NOISE_SUBJECTS = {
    "tarzan", "colonialism", "imperialism",
    "safari", "big game hunting", "missionaries",
}

COMIC_SUBJECTS = {
    "graphic novel", "graphic novels", "comics", "comic book",
    "comic strip", "sequential art",
}

# ── Add to filter: remove non-fiction / academic books ─────────────────────
NONFICTION_SUBJECTS = {
    "criticism", "critical essays", "literary criticism",
    "history and criticism", "congresses", "study and teaching",
    "nonfiction", "biography", "autobiography",
    "education", "philosophy", "sociology", "political science",
    "essays", "handbooks", "reference",
    "cross-cultural studies", "mass media", "self-perception",
    "creative ability in children", "imagination in children",
}

def ol_final_filter(row):
    author        = str(row.get("author", "")).lower().strip()
    subjects_text = " ".join(str(s) for s in (row.get("subjects") or [])).lower()

    if author in WESTERN_NOISE_AUTHORS:
        return False
    if any(n in subjects_text for n in NOISE_SUBJECTS):
        return False
    if any(c in subjects_text for c in COMIC_SUBJECTS):
        return False
    if any(n in subjects_text for n in NONFICTION_SUBJECTS):
        return False
    return True

ol_clean   = ol_raw[ol_raw.apply(ol_final_filter, axis=1)].copy().reset_index(drop=True)
ol_removed = ol_raw[~ol_raw.apply(ol_final_filter, axis=1)].copy().reset_index(drop=True)

print(f"── Final OL filter ──")
print(f"  Before:  {len(ol_raw):,}")
print(f"  After:   {len(ol_clean):,}")
print(f"  Removed: {len(ol_removed):,}")

print()
for t in ["Harry Potter", "Tarzan", "The Sword of Kaigen",
          "Spice Road", "Children of Blood and Bone"]:
    found = ol_clean[ol_clean["title"].str.contains(t, case=False, na=False)]
    status = f"✅ KEPT ({len(found)})" if len(found) else "❌ REMOVED"
    print(f"  {status}: {t}")

print(f"\nTop 30 authors:")
print(ol_clean["author"].value_counts().head(30).to_string())
# Out:
# ── Final OL filter ──
#   Before:  4,364
#   After:   2,355
#   Removed: 2,009
#
#   ❌ REMOVED: Harry Potter
#   ❌ REMOVED: Tarzan
#   ✅ KEPT (1): The Sword of Kaigen
#   ✅ KEPT (1): Spice Road
#   ✅ KEPT (1): Children of Blood and Bone
#
# Top 30 authors:
# author
#                         99
# Joseph Li               13
# Maya Daniels            13
# L. A. Banks             10
# 村上春樹                    10
# Tao Wong                10
# Lynne Reid Banks        10
# Vicki Corona            10
# Gillian Rubinstein       9
# Octavia E. Butler        8
# Reggie ROBINSON          8
# Lian Hearn               7
# Erica BAKER              7
# Hasaway Anime Corner     6
# Scott Walker             6
# Philip Kerr              6
# Tara Maya                6
# Lauren Beukes            5
# Samuel R. Delany         5
# Nalo Hopkinson           5
# A. J. Hartley            5
# Rochelle Alers           5
# Yuan, Mei                5
# Henriette Barkow         5
# Yoshitaka Amano          5
# Steve Bein               5
# Mo Xiang Tong Xiu        5
# Jami Fairleigh           5
# Roshani Chokshi          5
# Tom Deitz                5

# %%
# ── Quick debug ─────────────────────────────────────────────────────────────
hp = ol_clean[ol_clean["title"].str.contains("Harry Potter", case=False, na=False)]
print("Harry Potter entries:")
for _, r in hp.iterrows():
    print(f"  author: '{r['author']}' | query: {r['query']}")
# Out:
# Harry Potter entries:
#   author: 'Maya Götz' | query: fantasy maya
#   author: 'Maya Götz' | query: fantasy maya
#   author: 'Elizabeth E. Heilman' | query: fantasy navajo

# %%
hp = ol_clean[ol_clean["title"].str.contains("Harry Potter", case=False, na=False)]
for _, r in hp.iterrows():
    print(f"Title:    {r['title']}")
    print(f"Author:   {r['author']}")
    print(f"Subjects: {r['subjects']}")
    print(f"Query:    {r['query']}")
    print()
# Out:
# Title:    Mit Pokémon in Harry Potters Welt
# Author:   Maya Götz
# Subjects: ['Cross-cultural studies', 'Imagination in children', 'Role models', 'Mass media and children', 'Fantasy in children', 'Self-perception in children', 'Creative ability in children']
# Query:    fantasy maya
#
# Title:    Mit Pokémon in Harry Potters Welt
# Author:   Maya Götz
# Subjects: ['Cross-cultural studies', 'Imagination in children', 'Role models', 'Mass media and children', 'Fantasy in children', 'Self-perception in children', 'Creative ability in children']
# Query:    fantasy maya

# %%
# ── Check non-English titles ────────────────────────────────────────────────
from langdetect import detect

def is_english_title(title):
    try:
        return detect(str(title)) == "en"
    except:
        return True

non_english = ol_clean[~ol_clean["title"].apply(is_english_title)]
print(f"Non-English titles: {len(non_english):,}")
print(f"\nSample:")
for _, r in non_english.head(20).iterrows():
    print(f"  {r['title']} — {r['author']}")
# Out:
# Non-English titles: 947
#
# Sample:
#   Akata witch — Nnedi Okorafor
#   Coloring Book — animailloverit cor
#   Aesheba —
#   Beautiful Skin — Vlad Dima
#   Beyond Fantasy — Marialuisa Marino
#   Egyptomania — Ronald H. Fritze
#   Crota — Rohan M. Vider
#   Ape no Evil — Milika M
#   Bubbles — Miriam Jordan
#   Bugie coloniali — Alberto Alpozzi
#   Keystone Passage — Catherine L Quinlan
#   Neveryóna — Samuel R. Delany
#   Dominion — Zelda Knight
#   Mara and Dann — Doris Lessing
#   Keystone Passage — Catherine Quinlan
#   On The Steel Breeze — Alastair Reynolds
#   Kubu Tales - Book 1 — J. Ratcliffe
#   Célanire cou-coupé — Maryse Condé
#   Devil's valley — André Philippus Brink
#   Mojo — Nalo Hopkinson

# %%
# ── Check blank author books ────────────────────────────────────────────────
blank = ol_clean[ol_clean["author"].str.strip() == ""]
print(f"Books with no author: {len(blank)}")
print(f"\nSample:")
for _, r in blank.head(15).iterrows():
    print(f"  {r['title']} — query: {r['query']}")
# Out:
# Books with no author: 99
#
# Sample:
#   Aesheba — query: fantasy africa
#   Collection of 7 fantasy cards on sub-Sahara Africa missionaries — query: fantasy africa
#   Animals in Africa — query: fantasy africa
#   In and out of Africa — query: fantasy africa
#   She — query: fantasy africa
#   She — query: fantasy africa
#   She — query: fantasy africa
#   She — query: fantasy africa
#   She — query: fantasy africa
#   Zaiire The Prince of Kongo and The Necklace of Destiny — query: fantasy africa
#   African Myths and Legends - Folklore for all — query: fantasy african
#   THE FUTURE IS BLACK AFROFUTURISM — query: afrofuturism
#   Afro-Future Females: Black Writers Chart Science Fiction's Newest New-Wave Trajectory — query: afrofuturism
#   The Fantasy Country (3 Volumes) (Chinese Edition) — query: fantasy chinese
#   Fantasy in the New Millennium (Chinese Edition) — query: fantasy chinese

# %%
# ── Drop blank authors ──────────────────────────────────────────────────────
ol_clean = ol_clean[ol_clean["author"].str.strip() != ""].copy().reset_index(drop=True)
print(f"After dropping blank authors: {len(ol_clean):,}")
# Out:
# After dropping blank authors: 2,256

# %%
# ── Cell 7 — Normalize and merge ───────────────────────────────────────────
import re

def norm_title(t):
    t = str(t).lower().strip()
    t = re.sub(r'\s*[\(\[].*?[\)\]]\s*', ' ', t)  # remove (series #1) etc
    t = re.sub(r'\s+', ' ', t).strip()
    return t

def norm_author(a):
    return str(a).lower().strip()

# ── Unified schema for OL ──────────────────────────────────────────────────
ol_unified = pd.DataFrame({
    "title":          ol_clean["title"].str.strip(),
    "author":         ol_clean["author"].fillna(""),
    "description":    ol_clean["description"].fillna(""),
    "year_published": ol_clean["year_published"],
    "cover_url":      ol_clean["cover_url"].fillna(""),
    "avg_rating":     ol_clean["avg_rating"],
    "num_ratings":    ol_clean["num_ratings"],
    "subjects":       ol_clean["subjects"].apply(lambda x: x if isinstance(x, list) else []),
    "source":         "open_library",
    "source_url":     ol_clean["source_url"],
    "source_tag":     ol_clean["source_tag"],
    "title_norm":     ol_clean["title"].apply(norm_title),
    "author_norm":    ol_clean["author"].fillna("").apply(norm_author),
})

# ── Unified schema for Goodreads ───────────────────────────────────────────
gr_unified = pd.DataFrame({
    "title":          gr_raw["title"].str.strip(),
    "author":         gr_raw["author"].fillna(""),
    "description":    gr_raw["description"].fillna(""),
    "year_published": gr_raw["year_published"],
    "cover_url":      gr_raw["cover_url"].fillna(""),
    "avg_rating":     gr_raw["avg_rating"],
    "num_ratings":    gr_raw["num_ratings"],
    "subjects":       [[] for _ in range(len(gr_raw))],
    "source":         "goodreads",
    "source_url":     gr_raw["goodreads_url"],
    "source_tag":     gr_raw["shelf"],
    "title_norm":     gr_raw["title"].apply(norm_title),
    "author_norm":    gr_raw["author"].fillna("").apply(norm_author),
})

# ── Merge — Goodreads wins on overlap ─────────────────────────────────────
gr_lookup = {}
for _, row in gr_unified.iterrows():
    key = (row["title_norm"], row["author_norm"])
    gr_lookup[key] = row

enriched_ol = []
ol_matched  = 0

for _, row in ol_unified.iterrows():
    key      = (row["title_norm"], row["author_norm"])
    gr_match = gr_lookup.get(key)

    if gr_match is not None:
        ol_matched += 1
        row = row.copy()
        if gr_match["description"]:
            row["description"] = gr_match["description"]
        if gr_match["cover_url"]:
            row["cover_url"] = gr_match["cover_url"]
        if pd.notna(gr_match["avg_rating"]):
            row["avg_rating"] = gr_match["avg_rating"]
        if pd.notna(gr_match["num_ratings"]):
            row["num_ratings"] = gr_match["num_ratings"]
        if pd.notna(gr_match["year_published"]):
            row["year_published"] = gr_match["year_published"]
    enriched_ol.append(row)

ol_enriched = pd.DataFrame(enriched_ol)

# Add OL-only books (not already in Goodreads)
gr_keys = set(gr_lookup.keys())
ol_only = ol_enriched[
    ~ol_enriched.apply(lambda r: (r["title_norm"], r["author_norm"]) in gr_keys, axis=1)
]

merged = pd.concat([gr_unified, ol_only], ignore_index=True)
merged = merged.drop(columns=["title_norm", "author_norm"])

print(f"── Merge results ──")
print(f"  Goodreads books:        {len(gr_unified):,}")
print(f"  OL books matched to GR: {ol_matched:,}")
print(f"  OL-only books added:    {len(ol_only):,}")
print(f"  Total merged:           {len(merged):,}")
print(f"\n── Field coverage ──")
for col in ["title","author","description","year_published","cover_url","avg_rating","num_ratings","subjects"]:
    if col == "subjects":
        filled = merged[col].apply(lambda x: isinstance(x, list) and len(x) > 0).sum()
    elif col == "description":
        filled = merged[col].apply(lambda x: bool(str(x).strip()) and str(x).strip() != "nan").sum()
    else:
        filled = merged[col].notna().sum()
    print(f"  {col:20s}: {filled:,}/{len(merged):,} ({filled/len(merged)*100:.0f}%)")
# Out:
# ── Merge results ──
#   Goodreads books:        2,129
#   OL books matched to GR: 103
#   OL-only books added:    2,153
#   Total merged:           4,282
#
# ── Field coverage ──
#   title               : 4,282/4,282 (100%)
#   author              : 4,282/4,282 (100%)
#   description         : 2,108/4,282 (49%)
#   year_published      : 3,849/4,282 (90%)
#   cover_url           : 4,282/4,282 (100%)
#   avg_rating          : 2,249/4,282 (53%)
#   num_ratings         : 2,236/4,282 (52%)
#   subjects            : 1,739/4,282 (41%)

# %%
# ── Cell 8 — Save pre-enrichment file ──────────────────────────────────────
PRE_ENRICH_PATH = CLEAN_DIR / "merged_pre_enrichment.json"

# Convert subjects lists to JSON-safe format
merged_save = merged.copy()
merged_save["subjects"] = merged_save["subjects"].apply(
    lambda x: x if isinstance(x, list) else []
)

merged_save.to_json(PRE_ENRICH_PATH, orient="records", indent=2, force_ascii=False)
print(f"✅ Saved {len(merged_save):,} books to {PRE_ENRICH_PATH}")

# How many need descriptions?
needs_desc = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]
print(f"\nBooks needing descriptions: {len(needs_desc):,}")
print(f"  From OL source: {(needs_desc['source'] == 'open_library').sum():,}")
print(f"  From GR source: {(needs_desc['source'] == 'goodreads').sum():,}")
# Out:
# ✅ Saved 4,282 books to C:\Users\Ready2Use\Documents\my-folder\Ironhack-week10\Book-recommendations\Data\Clean\merged_pre_enrichment.json
#
# Books needing descriptions: 2,174
#   From OL source: 2,153
#   From GR source: 21

# %%
# ── Cell 9 — Google Books enrichment ───────────────────────────────────────
import os, time, json, requests
from dotenv import load_dotenv
from langdetect import detect
from tqdm.notebook import tqdm

load_dotenv()
GOOGLE_BOOKS_API_KEY = os.getenv("GOOGLE_BOOKS_API_KEY", "")
print(f"API key loaded: {'✅' if GOOGLE_BOOKS_API_KEY else '❌ missing'}")

GB_CKPT_PATH = CLEAN_DIR / "google_books_checkpoint.json"

def fetch_google_books_description(title, author=""):
    query  = f"{title} {author}".strip()
    url    = "https://www.googleapis.com/books/v1/volumes"
    params = {
        "q":          query,
        "maxResults": 5,
        "key":        GOOGLE_BOOKS_API_KEY,
        "fields":     "items(volumeInfo(title,authors,description,publishedDate,imageLinks))"
    }
    try:
        resp  = requests.get(url, params=params, timeout=10)
        resp.raise_for_status()
        items = resp.json().get("items", [])
        for item in items:
            info = item.get("volumeInfo", {})
            desc = info.get("description", "")
            if desc:
                try:
                    if detect(desc) == "en":
                        return {
                            "description": desc,
                            "cover_url":   info.get("imageLinks", {}).get("thumbnail", ""),
                        }
                except:
                    continue
        return None
    except:
        return None

# ── Load checkpoint if exists ──────────────────────────────────────────────
if GB_CKPT_PATH.exists():
    with open(GB_CKPT_PATH) as f:
        gb_results = json.load(f)
    print(f"Resuming — {len(gb_results):,} already done")
else:
    gb_results = {}
    print("Starting fresh")

# ── Only process books missing descriptions ────────────────────────────────
needs_desc = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)].copy()

remaining = needs_desc[~needs_desc["source_url"].isin(gb_results.keys())]
print(f"Total needing descriptions: {len(needs_desc):,}")
print(f"Already fetched:            {len(needs_desc) - len(remaining):,}")
print(f"Remaining to fetch:         {len(remaining):,}")

stats = {"filled": 0, "not_found": 0, "error": 0}

for i, (idx, row) in enumerate(tqdm(
    remaining.iterrows(),
    total=len(remaining),
    desc="Google Books",
    unit="book"
), 1):
    key    = row["source_url"]
    title  = row["title"]
    author = row["author"]

    try:
        result = fetch_google_books_description(title, author)
        gb_results[key] = result if result else {}
        if result:
            stats["filled"] += 1
        else:
            stats["not_found"] += 1
    except Exception as e:
        gb_results[key] = {}
        stats["error"] += 1

    if i % 100 == 0:
        with open(GB_CKPT_PATH, "w") as f:
            json.dump(gb_results, f)

    time.sleep(0.5)

# Final checkpoint save
with open(GB_CKPT_PATH, "w") as f:
    json.dump(gb_results, f)

print(f"\n✅ Google Books enrichment complete")
print(f"   Filled:    {stats['filled']:,}")
print(f"   Not found: {stats['not_found']:,}")
print(f"   Errors:    {stats['error']:,}")
# Out:
# API key loaded: ✅
# Starting fresh
# Total needing descriptions: 2,174
# Already fetched:            0
# Remaining to fetch:         2,174
# Google Books:   0%|          | 0/2174 [00:00<?, ?book/s]
# ✅ Google Books enrichment complete
#    Filled:    1,005
#    Not found: 1,169
#    Errors:    0

# %%
# ── Cell 10 — Merge Google Books results back ───────────────────────────────
gb_filled = 0
gb_cover   = 0

for idx, row in merged.iterrows():
    key     = row["source_url"]
    gb_data = gb_results.get(key, {})

    if gb_data.get("description") and not bool(str(row["description"]).strip()):
        merged.at[idx, "description"] = gb_data["description"]
        gb_filled += 1

    if gb_data.get("cover_url") and not bool(str(row["cover_url"]).strip()):
        merged.at[idx, "cover_url"] = gb_data["cover_url"]
        gb_cover += 1

print(f"✅ Merged Google Books results")
print(f"   Descriptions filled: {gb_filled:,}")
print(f"   Covers filled:       {gb_cover:,}")

still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]
print(f"   Still missing desc:  {len(still_missing):,}")
# Out:
# ✅ Merged Google Books results
#    Descriptions filled: 1,005
#    Covers filled:       382
#    Still missing desc:  1,169

# %%
# ── Cell 11 — OpenLibrary description enrichment ───────────────────────────
OL_DESC_CKPT_PATH = CLEAN_DIR / "ol_desc_checkpoint.json"

def fetch_ol_description(ol_url):
    # Extract work key from URL e.g. https://openlibrary.org/works/OL19330487W
    key = ol_url.replace("https://openlibrary.org", "")
    if not key.startswith("/works/"):
        return None
    try:
        r = requests.get(f"https://openlibrary.org{key}.json", timeout=10)
        r.raise_for_status()
        data = r.json()
        desc = data.get("description", "")
        # description can be a string or a dict with "value" key
        if isinstance(desc, dict):
            desc = desc.get("value", "")
        if desc and len(str(desc).strip()) > 20:
            return str(desc).strip()
        return None
    except:
        return None

# ── Load checkpoint ────────────────────────────────────────────────────────
if OL_DESC_CKPT_PATH.exists():
    with open(OL_DESC_CKPT_PATH) as f:
        ol_desc_results = json.load(f)
    print(f"Resuming — {len(ol_desc_results):,} already done")
else:
    ol_desc_results = {}
    print("Starting fresh")

# Only try OL source books still missing descriptions
still_missing = merged[
    merged["description"].apply(lambda x: not bool(str(x).strip()) or str(x).strip() == "nan") &
    (merged["source"] == "open_library")
]
remaining = still_missing[~still_missing["source_url"].isin(ol_desc_results.keys())]

print(f"OL books still missing desc: {len(still_missing):,}")
print(f"Remaining to fetch:          {len(remaining):,}")

stats = {"filled": 0, "not_found": 0}

for i, (idx, row) in enumerate(tqdm(
    remaining.iterrows(),
    total=len(remaining),
    desc="OL descriptions",
    unit="book"
), 1):
    key    = row["source_url"]
    result = fetch_ol_description(key)
    ol_desc_results[key] = result or ""

    if result:
        stats["filled"] += 1
    else:
        stats["not_found"] += 1

    if i % 100 == 0:
        with open(OL_DESC_CKPT_PATH, "w") as f:
            json.dump(ol_desc_results, f)

    time.sleep(0.3)

# Save checkpoint
with open(OL_DESC_CKPT_PATH, "w") as f:
    json.dump(ol_desc_results, f)

print(f"\n✅ OL description enrichment complete")
print(f"   Filled:    {stats['filled']:,}")
print(f"   Not found: {stats['not_found']:,}")
# Out:
# Starting fresh
# OL books still missing desc: 1,156
# Remaining to fetch:          1,156
# OL descriptions:   0%|          | 0/1156 [00:00<?, ?book/s]
# ✅ OL description enrichment complete
#    Filled:    295
#    Not found: 861

# %%
# ── Cell 12 — Merge OL description results back ────────────────────────────
ol_filled = 0

for idx, row in merged.iterrows():
    key     = row["source_url"]
    ol_desc = ol_desc_results.get(key, "")

    if ol_desc and not bool(str(row["description"]).strip()) or str(row["description"]).strip() == "nan":
        merged.at[idx, "description"] = ol_desc
        ol_filled += 1

still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]

print(f"✅ OL descriptions merged")
print(f"   Filled:             {ol_filled:,}")
print(f"   Still missing desc: {len(still_missing):,}")
print(f"   Source breakdown of missing:")
print(still_missing["source"].value_counts().to_string())
# Out:
# ✅ OL descriptions merged
#    Filled:             295
#    Still missing desc: 874
#    Source breakdown of missing:
# source
# open_library    861
# goodreads        13

# %%
# ── Audit the 874 missing description books ────────────────────────────────
still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)].copy()

print(f"Missing descriptions: {len(still_missing):,}")
print(f"\n── Rating distribution ──")
print(f"  Has ratings:    {still_missing['num_ratings'].notna().sum():,}")
print(f"  No ratings:     {still_missing['num_ratings'].isna().sum():,}")
print(f"  Median ratings: {still_missing['num_ratings'].median()}")

print(f"\n── Source tag breakdown ──")
print(still_missing["source_tag"].value_counts().to_string())

print(f"\n── Sample of missing books ──")
for _, r in still_missing.sample(20, random_state=42).iterrows():
    ratings = int(r['num_ratings']) if pd.notna(r['num_ratings']) else 0
    print(f"  {r['title'][:50]} — {r['author'][:30]} ({ratings} ratings)")
# Out:
# Missing descriptions: 874
#
# ── Rating distribution ──
#   Has ratings:    39
#   No ratings:     835
#   Median ratings: 2.0
#
# ── Source tag breakdown ──
# source_tag
# south_asian            190
# japanese               180
# middle_eastern         131
# latin_american         129
# chinese                 96
# wuxia                   29
# korean                  18
# africa                  17
# filipino                17
# southeast_asian         16
# xianxia                 11
# indigenous_americas     11
# oceania                 10
# afrofuturism             9
# asian-fantasy            6
# australian-fantasy       1
# akan                     1
# orisha                   1
# anansi                   1
#
# ── Sample of missing books ──
#   Magic Time: Angelfire — Maya Kaathryn Bonhoff (0 ratings)
#   中国革命史 — 孙武霞 (0 ratings)
#   Bombay before Bollywood — Rosie Thomas (0 ratings)
#   Quetzalcoatl — José López Portillo (0 ratings)
#   King's Fall — Aditya Wig (0 ratings)
#   Thousand Li : The Third Cut — Tao Wong (0 ratings)
#   Objeto no identificado y otros cuentos de ciencia  — Mariana Castillo Rojas (0 ratings)
#   Suezue — Megumi Hatakenaka (0 ratings)
#   The conference of the birds — Farīd al-Dīn ʻAṭṭār (0 ratings)
#   Tears of Starlight — Maya Claire (0 ratings)
#   Chris Lamb — Chris Chris Lamb (0 ratings)
#   Kitsune no mado — Naoko Awa (0 ratings)
#   Love Beyond Body, Space and Time: an Indigenous LG — Hope Nicholson (0 ratings)
#   Yowai — Shinji Ishii (0 ratings)
#   Slayers! Slayers(Chinese Edition) — SHEN BAN YI (0 ratings)
#   Twenty-Two Goblins; — Arthur W. 1877-1938 Ryder (0 ratings)
#   Chibi Girls Coloring Book — PHbook house (0 ratings)
#   Time's Convert — Deborah Harkness (0 ratings)
#   Composition Book — Robimo Press (0 ratings)
#   Tattoo Designs - Adult Coloring Book - Egyptian, G — Bountiful Artworks (0 ratings)

# %%
# ── Cell 13 — Final cleanup of no-description, no-rating books ─────────────

JUNK_TITLE_SIGNALS = [
    "coloring book", "composition book", "tattoo design",
    "chinese edition", "kindle edition", "activity book",
    "notebook", "journal", "sketchbook", "workbook",
]

def is_junk(row):
    title_lower = str(row.get("title", "")).lower()
    # No description AND no ratings AND junk title signal
    has_desc    = bool(str(row.get("description", "")).strip())
    has_ratings = pd.notna(row.get("num_ratings")) and row.get("num_ratings", 0) > 0
    if has_desc or has_ratings:
        return False
    return any(signal in title_lower for signal in JUNK_TITLE_SIGNALS)

junk_mask = merged.apply(is_junk, axis=1)
merged    = merged[~junk_mask].copy().reset_index(drop=True)
print(f"Removed junk books: {junk_mask.sum():,}")
print(f"Remaining: {len(merged):,}")

# ── Subjects fallback for remaining missing ─────────────────────────────────
fallback_filled = 0

for idx, row in merged.iterrows():
    has_desc = bool(str(row["description"]).strip()) and str(row["description"]).strip() != "nan"
    if has_desc:
        continue
    subjects = row["subjects"]
    if isinstance(subjects, list) and len(subjects) > 0:
        clean_subj = [str(s).strip() for s in subjects if len(str(s).strip()) > 2][:10]
        if clean_subj:
            merged.at[idx, "description"] = "A work of fantasy fiction involving: " + ", ".join(clean_subj) + "."
            fallback_filled += 1

still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]

print(f"\n✅ Fallback complete")
print(f"   Filled with subjects: {fallback_filled:,}")
print(f"   Still empty:          {len(still_missing):,}")
print(f"   Total books:          {len(merged):,}")
# Out:
# Removed junk books: 61
# Remaining: 4,221
#
# ✅ Fallback complete
#    Filled with subjects: 642
#    Still empty:          171
#    Total books:          4,221

# %%
# ── Check the 171 still empty ───────────────────────────────────────────────
still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)].copy()

print(f"Still missing: {len(still_missing)}")
print()
for _, r in still_missing.iterrows():
    ratings = int(r['num_ratings']) if pd.notna(r['num_ratings']) else 0
    subj    = str(r['subjects'])[:60] if r['subjects'] else "no subjects"
    print(f"  {r['title'][:50]} — {r['author'][:25]} ({ratings} ratings)")
    print(f"    subjects: {subj}")
# Out:
# Still missing: 171
#
#   Untitled - Legend of White Snake Retelling (Unknow — Sue Lynn Tan (8 ratings)
#     subjects: no subjects
#   Cats and Dragon - vol. 01 — Amara (0 ratings)
#     subjects: no subjects
#   Synthers & Beasts (Kindle Edition) — Judy  Liu (3 ratings)
#     subjects: no subjects
#   Shadow of the Ring T04 (Paperback) — Kaiji Nakagawa (4 ratings)
#     subjects: no subjects
#   Wa No Kage (Wa No Kage, #3) — Kaiji Nakagawa (5 ratings)
#     subjects: no subjects
#   Doga T01 (Paperback) — Tōryūmon Takeda (27 ratings)
#     subjects: no subjects
#   The Song of Wirrun: Ice is Coming, Dark Bright Wat — Patricia Wrightson (26 ratings)
#     subjects: no subjects
#   Vèvè-Punk: Birth of the Dream: Illustrated Short S — Dominick Rabrun (5 ratings)
#     subjects: no subjects
#   Afrofuturismo - vol.1 - O futuro é nosso (Paperbac — Aisameque Nguengue (6 ratings)
#     subjects: no subjects
#   Some Are Born To Endless Night - Dark Matter (Hard — Lina Iris Viktor (0 ratings)
#     subjects: no subjects
#   La cripta (Unknown Binding) — Felix Joaquín Rivera (7 ratings)
#     subjects: no subjects
#   A Spaceship in Bronzeville: Magi (Paperback) — Ytasha L. Womack (5 ratings)
#     subjects: no subjects
#   These Legs Were Made for Walking (Paperback) — Wayétu Moore (7 ratings)
#     subjects: no subjects
#   Words in the Wind — Demon L. A Wood (0 ratings)
#     subjects: no subjects
#   The Pilgrim Of Our Lady Of Martyrs — Apostleship of Prayer (Or (0 ratings)
#     subjects: no subjects
#   Legend of the Forest 2---Chinese Idioms — Feng QI (0 ratings)
#     subjects: no subjects
#   The wicked Wang-Pah meets a dragon — Floralyn Cadwell (0 ratings)
#     subjects: no subjects
#   Longevity of Wuxia_Part 4 — Joseph Li (0 ratings)
#     subjects: no subjects
#   Longevity of Wuxia_Part 3 — Joseph Li (0 ratings)
#     subjects: no subjects
#   Longevity of Wuxia_Part 8 — Joseph Li (0 ratings)
#     subjects: no subjects
#   The jade heart — Carol Coates (0 ratings)
#     subjects: no subjects
#   Grand Fantasy Designs - Notes — Felix Ode (0 ratings)
#     subjects: no subjects
#   Diabetes Tagebuch — Karl Simpson (0 ratings)
#     subjects: no subjects
#   Diabetes Tagebuch — Carl Simpson (0 ratings)
#     subjects: no subjects
#   Diabetes Tagebuch — Jason Piekser (0 ratings)
#     subjects: no subjects
#   The rape of the nation and the hymen fantasy — All Brock English Authors (0 ratings)
#     subjects: no subjects
#   Notizbuch — Kalender 2020 Planer (0 ratings)
#     subjects: no subjects
#   Notizbuch — Lennard Lennox (0 ratings)
#     subjects: no subjects
#   Death Notes - Special Edition — Kawaii Cuties Homeland (0 ratings)
#     subjects: no subjects
#   Classic Works of Japanese Fantasy Literature — (日)夏目漱石; 太宰治 (0 ratings)
#     subjects: no subjects
#   Final Fantasy X-2.5 novel (hardcover, Japanese) — Kazushige Nojima (0 ratings)
#     subjects: no subjects
#   Big fantasy literature. Japanese novels: the wind  — AN FANG ZHI ZI. XIAO ZE L (0 ratings)
#     subjects: no subjects
#   Learning from Shogun — ed Smith Henry (0 ratings)
#     subjects: no subjects
#   Final Fantasy Guitar Solo Collection (Fainaru Fant — Nobuo Uematsu (0 ratings)
#     subjects: no subjects
#   Apocripha/0 [G Fantasy C] Vol. 1 (Apokurifa/ Zero  — Azusa Yuuki (0 ratings)
#     subjects: no subjects
#   Apocripha/0 [G Fantasy C] Vol. 2 (Apokurifa/ Zero  — Azusa Yuuki (0 ratings)
#     subjects: no subjects
#   Spirited Away Trivia : Amazing about Japanese Anim — Martinie ANGELA (0 ratings)
#     subjects: no subjects
#   Genkoyoushi Paper — Sarah R. (0 ratings)
#     subjects: no subjects
#   Coloring Anime for Girls — Benny Fent (0 ratings)
#     subjects: no subjects
#   Music Sheet — Erica BAKER (0 ratings)
#     subjects: no subjects
#   Simple Weight Tracker — Reggie ROBINSON (0 ratings)
#     subjects: no subjects
#   Anime Colouring Book — Cibbi art (0 ratings)
#     subjects: no subjects
#   Anime Colouring Book — bella art (0 ratings)
#     subjects: no subjects
#   House Sitting Guide — Reggie ROBINSON (0 ratings)
#     subjects: no subjects
#   One Piece Color by Number — Zach Walsh (0 ratings)
#     subjects: no subjects
#   Personal Expense Tracker — Reggie ROBINSON (0 ratings)
#     subjects: no subjects
#   Reading List Book — Reggie ROBINSON (0 ratings)
#     subjects: no subjects
#   Self Care Acts Planner — Erica BAKER (0 ratings)
#     subjects: no subjects
#   Wuxia — A. Williams (0 ratings)
#     subjects: no subjects
#   方外群侠传FOREIGN WUXIA — Wiki (0 ratings)
#     subjects: no subjects
#   Wuxia America — Michael A. DeMarco (0 ratings)
#     subjects: no subjects
#   Der Wuxia-Film und die aktuelle Gesellschaft China — Gongpu Song (0 ratings)
#     subjects: no subjects
#   Langfaust — Tobias Reckermann (0 ratings)
#     subjects: no subjects
#   Wu Shuang Pu of Wuxia — Cedric Lab (0 ratings)
#     subjects: no subjects
#   Inheritance — Jones, Patricia (0 ratings)
#     subjects: no subjects
#   Tausend Li : Der Erste Schritt — Tao Wong (0 ratings)
#     subjects: no subjects
#   Girl at Sunset — Fabio Boaro (0 ratings)
#     subjects: no subjects
#   Ein Tausend Li — Tao Wong (0 ratings)
#     subjects: no subjects
#   Meister der Pyramiden — Artjom Vadimovic (0 ratings)
#     subjects: no subjects
#   王無瑕先生詩文集 — Pu Wang (0 ratings)
#     subjects: no subjects
#   Erzählen von China — Clemens von Haselberg (0 ratings)
#     subjects: no subjects
#   王無瑕先生詩集 — 王璞 (0 ratings)
#     subjects: no subjects
#   Ein Tausend Li : Der erste Halt — Tao Wong (0 ratings)
#     subjects: no subjects
#   Way of the Immortals 2 : Divine Madness — Harmon Cooper (0 ratings)
#     subjects: no subjects
#   Culture Specific Items in Chinese to English Video — Dariush Robertson (0 ratings)
#     subjects: no subjects
#   斷袖篇 — Wuxia'ameng (0 ratings)
#     subjects: no subjects
#   "Yunnan san cun" zai diao cha — Xianxia Wang (0 ratings)
#     subjects: no subjects
#   Chris Lamb — Chris Chris Lamb (0 ratings)
#     subjects: no subjects
#   Beware of Chicken 3 — Casualfarmer (0 ratings)
#     subjects: no subjects
#   Beware of Chicken 2 — Casualfarmer (0 ratings)
#     subjects: no subjects
#   Thousand Li : The Fourth Stage — Tao Wong (0 ratings)
#     subjects: no subjects
#   Thousand Li : The Third Cut — Tao Wong (0 ratings)
#     subjects: no subjects
#   Witchblood — Lissa Kasey (0 ratings)
#     subjects: no subjects
#   Apocalypse Cultivator — Jack Bryce (0 ratings)
#     subjects: no subjects
#   Apocalypse Cultivator 3 — Jack Bryce (0 ratings)
#     subjects: no subjects
#   Craesti City: A Portal Cultivation Fantasy Saga — Chris Vines (0 ratings)
#     subjects: no subjects
#   Treasure Hunter in Fantasy World 3 — Mythic Dust (0 ratings)
#     subjects: no subjects
#   Czepta : Escape from Babylon — Czepta Gold (0 ratings)
#     subjects: no subjects
#   Mask of the Fallen: a Cultivation/Progression Fant — Harmon Cooper (0 ratings)
#     subjects: no subjects
#   Failed Assassination of the Thunder God — K. Klein (0 ratings)
#     subjects: no subjects
#   This Young Master Is Not Cannon Fodder — Fuyu Dust (0 ratings)
#     subjects: no subjects
#   India — Rita Joshi (0 ratings)
#     subjects: no subjects
#   India Forever — Lilian Hasler (0 ratings)
#     subjects: no subjects
#   Enchanted Magical Fairy Folk a Fantasy World for I — Grace Divine (0 ratings)
#     subjects: no subjects
#   Fantasy and the Politics of Subversion — Mayurika Chakravorty (0 ratings)
#     subjects: no subjects
#   Humanity's Strings — Ritwick Bhattacharjee (0 ratings)
#     subjects: no subjects
#   American Indian Stories Fantasy Annotated Novel — Zitkála-Šá (0 ratings)
#     subjects: no subjects
#   Cubicle Farm Fantasy — Ranjit Sankar (0 ratings)
#     subjects: no subjects
#   The Droll Child — John Edgell (0 ratings)
#     subjects: no subjects
#   Fantasies of the Master Race — M. Annette Jaimes (0 ratings)
#     subjects: no subjects
#   American Dream for an Indian Immigrant — Jacqueline Christiano (0 ratings)
#     subjects: no subjects
#   Are We Having Fun Yet? — William Sanders (0 ratings)
#     subjects: no subjects
#   Atlas of Mysore Wars -1767-1799-Reality, Myths and — Agha Amin (0 ratings)
#     subjects: no subjects
#   Life on the Rez — Raymond K. Rugg (0 ratings)
#     subjects: no subjects
#   The Word and the World — Veena A Das (0 ratings)
#     subjects: no subjects
#   Twilight of the Fourth World — Charis and Carlos Mundy (0 ratings)
#     subjects: no subjects
#   Twilight of the Fourth World — Carlos & Charis Mundy (0 ratings)
#     subjects: no subjects
#   Ramsey Campbell, Probably — Ramsey Campbell (0 ratings)
#     subjects: no subjects
#   Password Log Book — Victoria Prescott (0 ratings)
#     subjects: no subjects
#   A commonplace book of thoughts, memories, and fanc — Mrs. Anna Jameson (0 ratings)
#     subjects: no subjects
#   Enchanted Magical Fairy Folk a Fantasy World for t — Grace Divine (0 ratings)
#     subjects: no subjects
#   Philippine Choreographies — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Folk Dances of the Philippines — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Folk Dances of the Philippines w/DVD Dance Demonst — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Fantasy Thai Cuisine. 25 Simple and Quick Recipes — Ryan Hart (0 ratings)
#     subjects: no subjects
#   Amazing Fantasies — Andy Thai (0 ratings)
#     subjects: no subjects
#   Fantasy Tales of the Arabian Nights — Razzab Shaikh (0 ratings)
#     subjects: no subjects
#   Enchantress an Arabian Fantasy — D. M. Raver (0 ratings)
#     subjects: no subjects
#   The Arabian horse in fact,fantasy and fiction — George H Conn (0 ratings)
#     subjects: no subjects
#   Arabian Horse in Fact, Fantasy, and Fiction — George H. (George Harold) (0 ratings)
#     subjects: no subjects
#   The works of Robert Louis Stevenson — Robert Louis Stevenson (0 ratings)
#     subjects: no subjects
#   The Thief of Bagdad — Achmed Abdullah (0 ratings)
#     subjects: no subjects
#   Djinn's Desire — Kailin Gow (0 ratings)
#     subjects: no subjects
#   Mark of the Djinn — Shiulie Ghosh (0 ratings)
#     subjects: no subjects
#   Ancestral Warrior — John Clarke (0 ratings)
#     subjects: no subjects
#   Epic of Future — Baktash Khamsehpour (0 ratings)
#     subjects: no subjects
#   Lure of Fantasy Islam — Stephen Kirby (0 ratings)
#     subjects: no subjects
#   Dark City — Serajul ISLAM (0 ratings)
#     subjects: no subjects
#   Errant — Ava Islam (0 ratings)
#     subjects: no subjects
#   Mythographic Color and Discover Frozen Fantasies — Taiful Islam (0 ratings)
#     subjects: no subjects
#   With Love, from Planet B — Zaayin Salaam (0 ratings)
#     subjects: no subjects
#   Food Fantasy FGBIBIGWNZ — Fairuz Rahman (0 ratings)
#     subjects: no subjects
#   Magical Explorer, Vol. 2 — Iris (0 ratings)
#     subjects: no subjects
#   Aztecs — Ree Soesbee (0 ratings)
#     subjects: no subjects
#   Fantasy Art — Maya Esmail (0 ratings)
#     subjects: no subjects
#   Mystical Fantasy — Maya Nadin (0 ratings)
#     subjects: no subjects
#   Black Hand — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Flesh Fantasy [The Ambrose Heights Vampires 1] — Maya Deleina (0 ratings)
#     subjects: no subjects
#   Instigated — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Investigated — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Infuriated — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Ignited — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Infiltrated — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Initiated — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Maya of the In-between — Sita Bennett (0 ratings)
#     subjects: no subjects
#   Initiate - the Unfinished Song Book 1 : (Young Adu — Tara Maya (0 ratings)
#     subjects: no subjects
#   Taboo - the Unfinished Song Book 2 : (Epic Fantasy — Tara Maya (0 ratings)
#     subjects: no subjects
#   Elsie's Dream World of Maya — H. de los Santos (0 ratings)
#     subjects: no subjects
#   Sacrifice - the Unfinished Song Book 3 : (Epic Fan — Tara Maya (0 ratings)
#     subjects: no subjects
#   Root - the Unfinished Song Book 4 : (Epic Fantasy  — Tara Maya (0 ratings)
#     subjects: no subjects
#   Blood - the Unfinished Song Book 6 : (Epic Fantasy — Tara Maya (0 ratings)
#     subjects: no subjects
#   Wing - the Unfinished Song Book 5 : (Epic Fantasy  — Tara Maya (0 ratings)
#     subjects: no subjects
#   Lower World — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Hellfire to Come — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Everlasting Fire — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Place of Torment — Maya Daniels (0 ratings)
#     subjects: no subjects
#   Maya's Magical Adventures — Maya McCoard (0 ratings)
#     subjects: no subjects
#   BABY BOSS Malbuch — maria maya (0 ratings)
#     subjects: no subjects
#   Metroplex Fantasy — Maya Mukherjee (0 ratings)
#     subjects: no subjects
#   Die Kleine Meerjungfrau Malbuch — maria maya (0 ratings)
#     subjects: no subjects
#   Star Trek Cookbook Appetizing Recipes — Maya Colt (0 ratings)
#     subjects: no subjects
#   Maya Mysun and the World That Does Not Exist : (a  — P. M. Perry (0 ratings)
#     subjects: no subjects
#   Unerwartetes Abenteuer - Wie Jonas, Maya und ein A — Abenteuer Lesen (0 ratings)
#     subjects: no subjects
#   Unerwartetes Abenteuer - Leichter Lesen - Wie Jona — Abenteuer Lesen (0 ratings)
#     subjects: no subjects
#   Solo Expedition : Exploring Fantasy Mayan World — Krysten Ballreich (0 ratings)
#     subjects: no subjects
#   Pishtaco — Mark Patton (0 ratings)
#     subjects: no subjects
#   Un viaje al país de las nubes — Mario Lamo-Jiménez (0 ratings)
#     subjects: no subjects
#   Latin American Science Fiction — M. Ginway (0 ratings)
#     subjects: no subjects
#   Posthumanism and Latin(x) American Science Fiction — Antonio Córdoba (0 ratings)
#     subjects: no subjects
#   Peter Lang Companion to Latin American Science Fic — Silvia G. Kurlat Ares (0 ratings)
#     subjects: no subjects
#   Tribal Fantasies — J. Mackay (0 ratings)
#     subjects: no subjects
#   Anthology of Short Stories - Volume II — Watts, John (0 ratings)
#     subjects: no subjects
#   Conscious : Shikoba Blue Series — DonnaLee Grimsley (0 ratings)
#     subjects: no subjects
#   Gay — Lee Lane Lamplight (0 ratings)
#     subjects: no subjects
#   Fact, fun and fantasy — Tyrone D. Campbell (0 ratings)
#     subjects: no subjects
#   Maori Tribe Choreographies — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Polynesian Choreographies — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Polynesian Dancing for Men — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Polynesian Choreographies (Book & Companion Audio  — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Exotic dances of Tonga: For female Polynesian danc — Vicki Corona (0 ratings)
#     subjects: no subjects
#   Polynesian Dancing For Men (Booklet w/Samoan Fire  — Vicki Corona (0 ratings)
#     subjects: no subjects

# %%
# ── Drop clear junk from the 171 ───────────────────────────────────────────
JUNK_SIGNALS = [
    "tagebuch", "notizbuch", "malbuch", "planer", "kalender",
    "coloring", "colouring", "color by number",
    "weight tracker", "expense tracker", "password log",
    "music sheet", "genkoyoushi", "house sitting",
    "self care", "reading list book",
    "choreograph", "dancing for", "folk dance",
    "cookbook", "recipes",
    "guitar solo", "guitar collection",
    "diabetes", "trivia",
    "food fantasy fgb",  # the random food book
]

def is_still_junk(row):
    has_desc    = bool(str(row.get("description", "")).strip()) and str(row.get("description","")).strip() != "nan"
    has_ratings = pd.notna(row.get("num_ratings")) and row.get("num_ratings", 0) > 0
    if has_desc or has_ratings:
        return False
    title_lower = str(row.get("title", "")).lower()
    return any(signal in title_lower for signal in JUNK_SIGNALS)

junk_mask2 = merged.apply(is_still_junk, axis=1)
merged     = merged[~junk_mask2].copy().reset_index(drop=True)
print(f"Removed: {junk_mask2.sum():,}")
print(f"Remaining: {len(merged):,}")

# ── Check what's still missing ─────────────────────────────────────────────
still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]
print(f"Still no description: {len(still_missing):,}")
print(f"\nRemaining no-description books:")
for _, r in still_missing.iterrows():
    ratings = int(r['num_ratings']) if pd.notna(r['num_ratings']) else 0
    print(f"  {r['title'][:55]} — {r['author'][:25]} ({ratings} ratings)")
# Out:
# Removed: 33
# Remaining: 4,188
# Still no description: 138
#
# Remaining no-description books:
#   Untitled - Legend of White Snake Retelling (Unknown Bin — Sue Lynn Tan (8 ratings)
#   Cats and Dragon - vol. 01 — Amara (0 ratings)
#   Synthers & Beasts (Kindle Edition) — Judy  Liu (3 ratings)
#   Shadow of the Ring T04 (Paperback) — Kaiji Nakagawa (4 ratings)
#   Wa No Kage (Wa No Kage, #3) — Kaiji Nakagawa (5 ratings)
#   Doga T01 (Paperback) — Tōryūmon Takeda (27 ratings)
#   The Song of Wirrun: Ice is Coming, Dark Bright Water an — Patricia Wrightson (26 ratings)
#   Vèvè-Punk: Birth of the Dream: Illustrated Short Story  — Dominick Rabrun (5 ratings)
#   Afrofuturismo - vol.1 - O futuro é nosso (Paperback) — Aisameque Nguengue (6 ratings)
#   Some Are Born To Endless Night - Dark Matter (Hardcover — Lina Iris Viktor (0 ratings)
#   La cripta (Unknown Binding) — Felix Joaquín Rivera (7 ratings)
#   A Spaceship in Bronzeville: Magi (Paperback) — Ytasha L. Womack (5 ratings)
#   These Legs Were Made for Walking (Paperback) — Wayétu Moore (7 ratings)
#   Words in the Wind — Demon L. A Wood (0 ratings)
#   The Pilgrim Of Our Lady Of Martyrs — Apostleship of Prayer (Or (0 ratings)
#   Legend of the Forest 2---Chinese Idioms — Feng QI (0 ratings)
#   The wicked Wang-Pah meets a dragon — Floralyn Cadwell (0 ratings)
#   Longevity of Wuxia_Part 4 — Joseph Li (0 ratings)
#   Longevity of Wuxia_Part 3 — Joseph Li (0 ratings)
#   Longevity of Wuxia_Part 8 — Joseph Li (0 ratings)
#   The jade heart — Carol Coates (0 ratings)
#   Grand Fantasy Designs - Notes — Felix Ode (0 ratings)
#   The rape of the nation and the hymen fantasy — All Brock English Authors (0 ratings)
#   Death Notes - Special Edition — Kawaii Cuties Homeland (0 ratings)
#   Classic Works of Japanese Fantasy Literature — (日)夏目漱石; 太宰治 (0 ratings)
#   Final Fantasy X-2.5 novel (hardcover, Japanese) — Kazushige Nojima (0 ratings)
#   Big fantasy literature. Japanese novels: the wind rolle — AN FANG ZHI ZI. XIAO ZE L (0 ratings)
#   Learning from Shogun — ed Smith Henry (0 ratings)
#   Apocripha/0 [G Fantasy C] Vol. 1 (Apokurifa/ Zero 0) (i — Azusa Yuuki (0 ratings)
#   Apocripha/0 [G Fantasy C] Vol. 2 (Apokurifa/ Zero 0) (i — Azusa Yuuki (0 ratings)
#   Wuxia — A. Williams (0 ratings)
#   方外群侠传FOREIGN WUXIA — Wiki (0 ratings)
#   Wuxia America — Michael A. DeMarco (0 ratings)
#   Der Wuxia-Film und die aktuelle Gesellschaft Chinas — Gongpu Song (0 ratings)
#   Langfaust — Tobias Reckermann (0 ratings)
#   Wu Shuang Pu of Wuxia — Cedric Lab (0 ratings)
#   Inheritance — Jones, Patricia (0 ratings)
#   Tausend Li : Der Erste Schritt — Tao Wong (0 ratings)
#   Girl at Sunset — Fabio Boaro (0 ratings)
#   Ein Tausend Li — Tao Wong (0 ratings)
#   Meister der Pyramiden — Artjom Vadimovic (0 ratings)
#   王無瑕先生詩文集 — Pu Wang (0 ratings)
#   Erzählen von China — Clemens von Haselberg (0 ratings)
#   王無瑕先生詩集 — 王璞 (0 ratings)
#   Ein Tausend Li : Der erste Halt — Tao Wong (0 ratings)
#   Way of the Immortals 2 : Divine Madness — Harmon Cooper (0 ratings)
#   Culture Specific Items in Chinese to English Video Game — Dariush Robertson (0 ratings)
#   斷袖篇 — Wuxia'ameng (0 ratings)
#   "Yunnan san cun" zai diao cha — Xianxia Wang (0 ratings)
#   Chris Lamb — Chris Chris Lamb (0 ratings)
#   Beware of Chicken 3 — Casualfarmer (0 ratings)
#   Beware of Chicken 2 — Casualfarmer (0 ratings)
#   Thousand Li : The Fourth Stage — Tao Wong (0 ratings)
#   Thousand Li : The Third Cut — Tao Wong (0 ratings)
#   Witchblood — Lissa Kasey (0 ratings)
#   Apocalypse Cultivator — Jack Bryce (0 ratings)
#   Apocalypse Cultivator 3 — Jack Bryce (0 ratings)
#   Craesti City: A Portal Cultivation Fantasy Saga — Chris Vines (0 ratings)
#   Treasure Hunter in Fantasy World 3 — Mythic Dust (0 ratings)
#   Czepta : Escape from Babylon — Czepta Gold (0 ratings)
#   Mask of the Fallen: a Cultivation/Progression Fantasy S — Harmon Cooper (0 ratings)
#   Failed Assassination of the Thunder God — K. Klein (0 ratings)
#   This Young Master Is Not Cannon Fodder — Fuyu Dust (0 ratings)
#   India — Rita Joshi (0 ratings)
#   India Forever — Lilian Hasler (0 ratings)
#   Enchanted Magical Fairy Folk a Fantasy World for INDIA — Grace Divine (0 ratings)
#   Fantasy and the Politics of Subversion — Mayurika Chakravorty (0 ratings)
#   Humanity's Strings — Ritwick Bhattacharjee (0 ratings)
#   American Indian Stories Fantasy Annotated Novel — Zitkála-Šá (0 ratings)
#   Cubicle Farm Fantasy — Ranjit Sankar (0 ratings)
#   The Droll Child — John Edgell (0 ratings)
#   Fantasies of the Master Race — M. Annette Jaimes (0 ratings)
#   American Dream for an Indian Immigrant — Jacqueline Christiano (0 ratings)
#   Are We Having Fun Yet? — William Sanders (0 ratings)
#   Atlas of Mysore Wars -1767-1799-Reality, Myths and Fant — Agha Amin (0 ratings)
#   Life on the Rez — Raymond K. Rugg (0 ratings)
#   The Word and the World — Veena A Das (0 ratings)
#   Twilight of the Fourth World — Charis and Carlos Mundy (0 ratings)
#   Twilight of the Fourth World — Carlos & Charis Mundy (0 ratings)
#   Ramsey Campbell, Probably — Ramsey Campbell (0 ratings)
#   A commonplace book of thoughts, memories, and fancies — Mrs. Anna Jameson (0 ratings)
#   Enchanted Magical Fairy Folk a Fantasy World for the Ph — Grace Divine (0 ratings)
#   Amazing Fantasies — Andy Thai (0 ratings)
#   Fantasy Tales of the Arabian Nights — Razzab Shaikh (0 ratings)
#   Enchantress an Arabian Fantasy — D. M. Raver (0 ratings)
#   The Arabian horse in fact,fantasy and fiction — George H Conn (0 ratings)
#   Arabian Horse in Fact, Fantasy, and Fiction — George H. (George Harold) (0 ratings)
#   The works of Robert Louis Stevenson — Robert Louis Stevenson (0 ratings)
#   The Thief of Bagdad — Achmed Abdullah (0 ratings)
#   Djinn's Desire — Kailin Gow (0 ratings)
#   Mark of the Djinn — Shiulie Ghosh (0 ratings)
#   Ancestral Warrior — John Clarke (0 ratings)
#   Epic of Future — Baktash Khamsehpour (0 ratings)
#   Lure of Fantasy Islam — Stephen Kirby (0 ratings)
#   Dark City — Serajul ISLAM (0 ratings)
#   Errant — Ava Islam (0 ratings)
#   Mythographic Color and Discover Frozen Fantasies — Taiful Islam (0 ratings)
#   With Love, from Planet B — Zaayin Salaam (0 ratings)
#   Magical Explorer, Vol. 2 — Iris (0 ratings)
#   Aztecs — Ree Soesbee (0 ratings)
#   Fantasy Art — Maya Esmail (0 ratings)
#   Mystical Fantasy — Maya Nadin (0 ratings)
#   Black Hand — Maya Daniels (0 ratings)
#   Flesh Fantasy [The Ambrose Heights Vampires 1] — Maya Deleina (0 ratings)
#   Instigated — Maya Daniels (0 ratings)
#   Investigated — Maya Daniels (0 ratings)
#   Infuriated — Maya Daniels (0 ratings)
#   Ignited — Maya Daniels (0 ratings)
#   Infiltrated — Maya Daniels (0 ratings)
#   Initiated — Maya Daniels (0 ratings)
#   Maya of the In-between — Sita Bennett (0 ratings)
#   Initiate - the Unfinished Song Book 1 : (Young Adult Ep — Tara Maya (0 ratings)
#   Taboo - the Unfinished Song Book 2 : (Epic Fantasy Magi — Tara Maya (0 ratings)
#   Elsie's Dream World of Maya — H. de los Santos (0 ratings)
#   Sacrifice - the Unfinished Song Book 3 : (Epic Fantasy  — Tara Maya (0 ratings)
#   Root - the Unfinished Song Book 4 : (Epic Fantasy Magic — Tara Maya (0 ratings)
#   Blood - the Unfinished Song Book 6 : (Epic Fantasy Magi — Tara Maya (0 ratings)
#   Wing - the Unfinished Song Book 5 : (Epic Fantasy Magic — Tara Maya (0 ratings)
#   Lower World — Maya Daniels (0 ratings)
#   Hellfire to Come — Maya Daniels (0 ratings)
#   Everlasting Fire — Maya Daniels (0 ratings)
#   Place of Torment — Maya Daniels (0 ratings)
#   Maya's Magical Adventures — Maya McCoard (0 ratings)
#   Metroplex Fantasy — Maya Mukherjee (0 ratings)
#   Maya Mysun and the World That Does Not Exist : (a Magic — P. M. Perry (0 ratings)
#   Unerwartetes Abenteuer - Wie Jonas, Maya und ein Alter  — Abenteuer Lesen (0 ratings)
#   Unerwartetes Abenteuer - Leichter Lesen - Wie Jonas, Ma — Abenteuer Lesen (0 ratings)
#   Solo Expedition : Exploring Fantasy Mayan World — Krysten Ballreich (0 ratings)
#   Pishtaco — Mark Patton (0 ratings)
#   Un viaje al país de las nubes — Mario Lamo-Jiménez (0 ratings)
#   Latin American Science Fiction — M. Ginway (0 ratings)
#   Posthumanism and Latin(x) American Science Fiction — Antonio Córdoba (0 ratings)
#   Peter Lang Companion to Latin American Science Fiction — Silvia G. Kurlat Ares (0 ratings)
#   Tribal Fantasies — J. Mackay (0 ratings)
#   Anthology of Short Stories - Volume II — Watts, John (0 ratings)
#   Conscious : Shikoba Blue Series — DonnaLee Grimsley (0 ratings)
#   Gay — Lee Lane Lamplight (0 ratings)
#   Fact, fun and fantasy — Tyrone D. Campbell (0 ratings)

# %%
# ── Manual decisions ────────────────────────────────────────────────────────
MANUAL_REMOVE_TITLES = {
    "black hand", "flesh fantasy", "instigated", "investigated",
    "infuriated", "ignited", "infiltrated", "initiated", "hellfire to come",
    "everlasting fire", "place of torment", "lower world",
    "the arabian horse in fact,fantasy and fiction",
    "arabian horse in fact, fantasy, and fiction",
    "the works of robert louis stevenson",
    "lure of fantasy islam", "atlas of mysore wars",
    "fantasies of the master race", "american dream for an indian immigrant",
    "india", "india forever", "enchanted magical fairy folk a fantasy world for india",
    "enchanted magical fairy folk a fantasy world for t",
    "fantasy and the politics of subversion",
    "culture specific items in chinese to english video",
    "tausend li : der erste schritt", "ein tausend li",
    "ein tausend li : der erste halt",
    "learning from shogun", "grand fantasy designs - notes",
    "the rape of the nation and the hymen fantasy",
    "cubicle farm fantasy", "ancestral warrior",
    "maya's magical adventures", "baby boss malbuch",
    "die kleine meerjungfrau malbuch",
    "star trek cookbook appetizing recipes",
    "amazing fantasies", "fantasy thai cuisine",
    "fantasy art", "mystical fantasy",
    "fact, fun and fantasy", "gay",
}

def is_manual_remove(row):
    has_desc = bool(str(row.get("description","")).strip()) and str(row.get("description","")).strip() != "nan"
    if has_desc:
        return False
    return str(row.get("title","")).lower().strip() in MANUAL_REMOVE_TITLES

mask3  = merged.apply(is_manual_remove, axis=1)
merged = merged[~mask3].copy().reset_index(drop=True)
print(f"Removed: {mask3.sum():,}")
print(f"Remaining: {len(merged):,}")

still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]
print(f"Still no description: {len(still_missing):,}")
print(f"\nFinal no-description books:")
for _, r in still_missing.iterrows():
    ratings = int(r['num_ratings']) if pd.notna(r['num_ratings']) else 0
    print(f"  {r['title'][:55]} — {r['author'][:25]} ({ratings} ratings)")
# Out:
# Removed: 35
# Remaining: 4,153
# Still no description: 103
#
# Final no-description books:
#   Untitled - Legend of White Snake Retelling (Unknown Bin — Sue Lynn Tan (8 ratings)
#   Cats and Dragon - vol. 01 — Amara (0 ratings)
#   Synthers & Beasts (Kindle Edition) — Judy  Liu (3 ratings)
#   Shadow of the Ring T04 (Paperback) — Kaiji Nakagawa (4 ratings)
#   Wa No Kage (Wa No Kage, #3) — Kaiji Nakagawa (5 ratings)
#   Doga T01 (Paperback) — Tōryūmon Takeda (27 ratings)
#   The Song of Wirrun: Ice is Coming, Dark Bright Water an — Patricia Wrightson (26 ratings)
#   Vèvè-Punk: Birth of the Dream: Illustrated Short Story  — Dominick Rabrun (5 ratings)
#   Afrofuturismo - vol.1 - O futuro é nosso (Paperback) — Aisameque Nguengue (6 ratings)
#   Some Are Born To Endless Night - Dark Matter (Hardcover — Lina Iris Viktor (0 ratings)
#   La cripta (Unknown Binding) — Felix Joaquín Rivera (7 ratings)
#   A Spaceship in Bronzeville: Magi (Paperback) — Ytasha L. Womack (5 ratings)
#   These Legs Were Made for Walking (Paperback) — Wayétu Moore (7 ratings)
#   Words in the Wind — Demon L. A Wood (0 ratings)
#   The Pilgrim Of Our Lady Of Martyrs — Apostleship of Prayer (Or (0 ratings)
#   Legend of the Forest 2---Chinese Idioms — Feng QI (0 ratings)
#   The wicked Wang-Pah meets a dragon — Floralyn Cadwell (0 ratings)
#   Longevity of Wuxia_Part 4 — Joseph Li (0 ratings)
#   Longevity of Wuxia_Part 3 — Joseph Li (0 ratings)
#   Longevity of Wuxia_Part 8 — Joseph Li (0 ratings)
#   The jade heart — Carol Coates (0 ratings)
#   Death Notes - Special Edition — Kawaii Cuties Homeland (0 ratings)
#   Classic Works of Japanese Fantasy Literature — (日)夏目漱石; 太宰治 (0 ratings)
#   Final Fantasy X-2.5 novel (hardcover, Japanese) — Kazushige Nojima (0 ratings)
#   Big fantasy literature. Japanese novels: the wind rolle — AN FANG ZHI ZI. XIAO ZE L (0 ratings)
#   Apocripha/0 [G Fantasy C] Vol. 1 (Apokurifa/ Zero 0) (i — Azusa Yuuki (0 ratings)
#   Apocripha/0 [G Fantasy C] Vol. 2 (Apokurifa/ Zero 0) (i — Azusa Yuuki (0 ratings)
#   Wuxia — A. Williams (0 ratings)
#   方外群侠传FOREIGN WUXIA — Wiki (0 ratings)
#   Wuxia America — Michael A. DeMarco (0 ratings)
#   Der Wuxia-Film und die aktuelle Gesellschaft Chinas — Gongpu Song (0 ratings)
#   Langfaust — Tobias Reckermann (0 ratings)
#   Wu Shuang Pu of Wuxia — Cedric Lab (0 ratings)
#   Inheritance — Jones, Patricia (0 ratings)
#   Girl at Sunset — Fabio Boaro (0 ratings)
#   Meister der Pyramiden — Artjom Vadimovic (0 ratings)
#   王無瑕先生詩文集 — Pu Wang (0 ratings)
#   Erzählen von China — Clemens von Haselberg (0 ratings)
#   王無瑕先生詩集 — 王璞 (0 ratings)
#   Way of the Immortals 2 : Divine Madness — Harmon Cooper (0 ratings)
#   Culture Specific Items in Chinese to English Video Game — Dariush Robertson (0 ratings)
#   斷袖篇 — Wuxia'ameng (0 ratings)
#   "Yunnan san cun" zai diao cha — Xianxia Wang (0 ratings)
#   Chris Lamb — Chris Chris Lamb (0 ratings)
#   Beware of Chicken 3 — Casualfarmer (0 ratings)
#   Beware of Chicken 2 — Casualfarmer (0 ratings)
#   Thousand Li : The Fourth Stage — Tao Wong (0 ratings)
#   Thousand Li : The Third Cut — Tao Wong (0 ratings)
#   Witchblood — Lissa Kasey (0 ratings)
#   Apocalypse Cultivator — Jack Bryce (0 ratings)
#   Apocalypse Cultivator 3 — Jack Bryce (0 ratings)
#   Craesti City: A Portal Cultivation Fantasy Saga — Chris Vines (0 ratings)
#   Treasure Hunter in Fantasy World 3 — Mythic Dust (0 ratings)
#   Czepta : Escape from Babylon — Czepta Gold (0 ratings)
#   Mask of the Fallen: a Cultivation/Progression Fantasy S — Harmon Cooper (0 ratings)
#   Failed Assassination of the Thunder God — K. Klein (0 ratings)
#   This Young Master Is Not Cannon Fodder — Fuyu Dust (0 ratings)
#   Humanity's Strings — Ritwick Bhattacharjee (0 ratings)
#   American Indian Stories Fantasy Annotated Novel — Zitkála-Šá (0 ratings)
#   The Droll Child — John Edgell (0 ratings)
#   Are We Having Fun Yet? — William Sanders (0 ratings)
#   Atlas of Mysore Wars -1767-1799-Reality, Myths and Fant — Agha Amin (0 ratings)
#   Life on the Rez — Raymond K. Rugg (0 ratings)
#   The Word and the World — Veena A Das (0 ratings)
#   Twilight of the Fourth World — Charis and Carlos Mundy (0 ratings)
#   Twilight of the Fourth World — Carlos & Charis Mundy (0 ratings)
#   Ramsey Campbell, Probably — Ramsey Campbell (0 ratings)
#   A commonplace book of thoughts, memories, and fancies — Mrs. Anna Jameson (0 ratings)
#   Enchanted Magical Fairy Folk a Fantasy World for the Ph — Grace Divine (0 ratings)
#   Fantasy Tales of the Arabian Nights — Razzab Shaikh (0 ratings)
#   Enchantress an Arabian Fantasy — D. M. Raver (0 ratings)
#   The Thief of Bagdad — Achmed Abdullah (0 ratings)
#   Djinn's Desire — Kailin Gow (0 ratings)
#   Mark of the Djinn — Shiulie Ghosh (0 ratings)
#   Epic of Future — Baktash Khamsehpour (0 ratings)
#   Dark City — Serajul ISLAM (0 ratings)
#   Errant — Ava Islam (0 ratings)
#   Mythographic Color and Discover Frozen Fantasies — Taiful Islam (0 ratings)
#   With Love, from Planet B — Zaayin Salaam (0 ratings)
#   Magical Explorer, Vol. 2 — Iris (0 ratings)
#   Aztecs — Ree Soesbee (0 ratings)
#   Flesh Fantasy [The Ambrose Heights Vampires 1] — Maya Deleina (0 ratings)
#   Maya of the In-between — Sita Bennett (0 ratings)
#   Initiate - the Unfinished Song Book 1 : (Young Adult Ep — Tara Maya (0 ratings)
#   Taboo - the Unfinished Song Book 2 : (Epic Fantasy Magi — Tara Maya (0 ratings)
#   Elsie's Dream World of Maya — H. de los Santos (0 ratings)
#   Sacrifice - the Unfinished Song Book 3 : (Epic Fantasy  — Tara Maya (0 ratings)
#   Root - the Unfinished Song Book 4 : (Epic Fantasy Magic — Tara Maya (0 ratings)
#   Blood - the Unfinished Song Book 6 : (Epic Fantasy Magi — Tara Maya (0 ratings)
#   Wing - the Unfinished Song Book 5 : (Epic Fantasy Magic — Tara Maya (0 ratings)
#   Metroplex Fantasy — Maya Mukherjee (0 ratings)
#   Maya Mysun and the World That Does Not Exist : (a Magic — P. M. Perry (0 ratings)
#   Unerwartetes Abenteuer - Wie Jonas, Maya und ein Alter  — Abenteuer Lesen (0 ratings)
#   Unerwartetes Abenteuer - Leichter Lesen - Wie Jonas, Ma — Abenteuer Lesen (0 ratings)
#   Solo Expedition : Exploring Fantasy Mayan World — Krysten Ballreich (0 ratings)
#   Pishtaco — Mark Patton (0 ratings)
#   Un viaje al país de las nubes — Mario Lamo-Jiménez (0 ratings)
#   Latin American Science Fiction — M. Ginway (0 ratings)
#   Posthumanism and Latin(x) American Science Fiction — Antonio Córdoba (0 ratings)
#   Peter Lang Companion to Latin American Science Fiction — Silvia G. Kurlat Ares (0 ratings)
#   Tribal Fantasies — J. Mackay (0 ratings)
#   Anthology of Short Stories - Volume II — Watts, John (0 ratings)
#   Conscious : Shikoba Blue Series — DonnaLee Grimsley (0 ratings)

# %%
# ── Final cleanup — drop non-novels with no description ────────────────────

# Books to explicitly KEEP despite no description
KEEP_TITLES = {
    "untitled - legend of white snake retelling",
    "synthers & beasts",
    "the song of wirrun: ice is coming, dark bright water an",
    "vèvè-punk: birth of the dream: illustrated short story",
    "afrofuturismo - vol.1 - o futuro é nosso",
    "a spaceship in bronzeville: magi",
    "these legs were made for walking",
    "beware of chicken 3", "beware of chicken 2",
    "thousand li : the fourth stage", "thousand li : the third cut",
    "apocalypse cultivator", "apocalypse cultivator 3",
    "this young master is not cannon fodder",
    "failed assassination of the thunder god",
    "mask of the fallen: a cultivation/progression fantasy s",
    "way of the immortals 2 : divine madness",
    "humanity's strings",
    "american indian stories fantasy annotated novel",
    "twilight of the fourth world",
    "djinn's desire", "mark of the djinn",
    "with love, from planet b",
    "magical explorer, vol. 2",
    "the thief of bagdad",
    "enchantress an Arabian fantasy",
    "fantasy tales of the arabian nights",
    "pishtaco",
    "conscious : shikoba blue series",
    "shadow of the ring t04",
    "wa no kage (wa no kage, #3)",
    "doga t01",
    "craesti city: a portal cultivation fantasy saga",
    "treasure hunter in fantasy world 3",
}

# Everything else with no description and no ratings gets dropped
def is_final_junk(row):
    has_desc    = bool(str(row.get("description","")).strip()) and str(row.get("description","")).strip() != "nan"
    has_ratings = pd.notna(row.get("num_ratings")) and row.get("num_ratings", 0) > 0
    if has_desc or has_ratings:
        return False
    title_lower = str(row.get("title","")).lower().strip()
    if title_lower in KEEP_TITLES:
        return False
    return True

mask4  = merged.apply(is_final_junk, axis=1)
merged = merged[~mask4].copy().reset_index(drop=True)

print(f"Removed: {mask4.sum():,}")
print(f"Remaining: {len(merged):,}")

still_missing = merged[merged["description"].apply(
    lambda x: not bool(str(x).strip()) or str(x).strip() == "nan"
)]
print(f"Still no description: {len(still_missing):,}")
print(f"\n── Final field coverage ──")
total = len(merged)
for col in ["title","author","description","year_published","cover_url","avg_rating","num_ratings"]:
    if col == "description":
        filled = merged[col].apply(lambda x: bool(str(x).strip()) and str(x).strip() != "nan").sum()
    else:
        filled = merged[col].notna().sum()
    print(f"  {col:20s}: {filled:,}/{total:,} ({filled/total*100:.0f}%)")
# Out:
# Removed: 69
# Remaining: 4,084
# Still no description: 34
#
# ── Final field coverage ──
#   title               : 4,084/4,084 (100%)
#   author              : 4,084/4,084 (100%)
#   description         : 4,050/4,084 (99%)
#   year_published      : 3,656/4,084 (90%)
#   cover_url           : 4,084/4,084 (100%)
#   avg_rating          : 2,249/4,084 (55%)
#   num_ratings         : 2,236/4,084 (55%)

# %%
# ── Cell 15 — Final dedup + save ───────────────────────────────────────────
before = len(merged)

# Normalize for dedup
merged["_title_norm"] = merged["title"].str.lower().str.strip()
merged["_author_norm"] = merged["author"].str.lower().str.strip()

# Keep goodreads version if duplicate (better metadata)
merged["_source_rank"] = merged["source"].map({"goodreads": 0, "open_library": 1})
merged = merged.sort_values("_source_rank").drop_duplicates(
    subset=["_title_norm", "_author_norm"], keep="first"
).drop(columns=["_title_norm", "_author_norm", "_source_rank"])
merged = merged.reset_index(drop=True)

print(f"Duplicates removed: {before - len(merged):,}")
print(f"Final count: {len(merged):,}")

# ── Save ───────────────────────────────────────────────────────────────────
FINAL_PATH = CLEAN_DIR / "merged_non_western_fantasy.json"
merged["subjects"] = merged["subjects"].apply(lambda x: x if isinstance(x, list) else [])
merged.to_json(FINAL_PATH, orient="records", indent=2, force_ascii=False)
merged.to_csv(CLEAN_DIR / "merged_non_western_fantasy.csv", index=False)

print(f"\n✅ NB03 complete!")
print(f"   Saved to {FINAL_PATH}")
# Out:
# Duplicates removed: 67
# Final count: 4,017
#
# ✅ NB03 complete!
#    Saved to C:\Users\Ready2Use\Documents\my-folder\Ironhack-week10\Book-recommendations\Data\Clean\merged_non_western_fantasy.json
